# %%
import pandas as pd
import numpy as np
import collections
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud
from gensim.models import word2vec
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from matplotlib import pyplot
from scipy import spatial
from sklearn.manifold import TSNE
from sklearn.manifold import LocallyLinearEmbedding

# %%
ingredients_df = pd.read_csv('../db/datas/ingredients.csv', sep=";")
recipes_df = pd.read_csv('../db/datas/recipes_new.csv',sep=";")
print(ingredients_df.shape)
print(recipes_df.shape)
# Out:
# (1035, 5)
# (115, 12)

# %%
ingredients_df.head(4)
# Out:
#                    uuid quantity  unit       name category
# 0  666995576ae7c8be50c7      800     g  oat bread   Bakery
# 1  b1997b662d682300b081        2  tbsp    gelatin   Bakery
# 2  a5ad2b18ce6a8cf1137f       18  tbsp   biscuits   Bakery
# 3  b3802daafb8b2121e09b      200     g   biscuits   Bakery

# %%
recipes_df.head(3)
# Out:
#                    uuid  global_rating  number_of_ratings  \
# 0  24d25b308700d23f709b              5                 32
# 1  8b1fcfc80c7231df0d48              5                278
# 2  74195811e951e9fbe3f8              5                276
#
#                                                 name  \
# 0  Butternut squash soup with chilli & crème fraîche
# 1                             Moroccan chickpea soup
# 2                            Broccoli & stilton soup
#
#                                                steps meal_type       origin  \
# 0  Heat oven to 200C/180C fan/gas 6.Cut 1 peeled ...   starter      English
# 1  Heat the oil in a large saucepan, then fry the...   starter  Middle East
# 2  Heat 2 tbsp rapeseed oil in a large saucepan a...   starter      English
#
#    prep_time  servings                                        description  \
# 0         65         4  Come in from the cold to a warming bowlful of ...
# 1         25         4  Try something different for vegetarians with M...
# 2         45         4  A smooth blended vegetable soup with blue chee...
#
#   difficulty                                          photo_url
# 0       Easy  www.bbcgoodfood.com/sites/default/files/styles...
# 1       Easy  www.bbcgoodfood.com/sites/default/files/styles...
# 2       Easy  www.bbcgoodfood.com/sites/default/files/styles...

# %%
ingredients_by_recipe = ingredients_df[["uuid", "name"]].groupby(['uuid']).agg({'name':lambda x: list(x)})
ingredients_by_recipe["ingredient_category_list"] = ingredients_df[["uuid", "category"]].groupby(['uuid']).agg({'category': lambda y: list(y)})
ingredients_by_recipe["num_of_ingredients"] = ingredients_df[["uuid", "name"]].groupby(['uuid']).size()
ingredients_by_recipe.columns = ["ingredient_list","ingredient_category_list","num_of_ingredients"]
ingredients_by_recipe.head(4)
# Out:
#                                                         ingredient_list  \
# uuid
# 02f1939873c5ed70986c  [red wine, olive oil, butter, cheddar, lentils...
# 0412d199f71146f42257  [butter, cheddar, milk, yogurt, flour, peas, b...
# 0528174c0168ac50d4d4  [tomato sauce, olive oil, butter, cheddar, mil...
# 0992b75fd5a8cc6a3e3e  [butter, cream, flour, bay leaf, garlic, parsl...
#
#                                                ingredient_category_list  \
# uuid
# 02f1939873c5ed70986c  [Beverage Alcoholic, Condiment, Dairy, Dairy, ...
# 0412d199f71146f42257  [Dairy, Dairy, Dairy, Dairy, Dry, Dry, Vegetab...
# 0528174c0168ac50d4d4  [Canned Goods, Condiment, Dairy, Dairy, Dairy,...
# 0992b75fd5a8cc6a3e3e  [Dairy, Dairy, Dry, Herb and Spice, Herb and S...
#
#                       num_of_ingredients
# uuid
# 02f1939873c5ed70986c                  11
# 0412d199f71146f42257                  12
# 0528174c0168ac50d4d4                  16
# 0992b75fd5a8cc6a3e3e                   9

# %%
recipes_df_joined = pd.merge(recipes_df, ingredients_by_recipe, on='uuid')
print(recipes_df_joined.shape)
# Out:
# (115, 15)

# %%
recipes_df_joined
# Out:
#                      uuid  global_rating  number_of_ratings  \
# 0    24d25b308700d23f709b              5                 32
# 1    8b1fcfc80c7231df0d48              5                278
# 2    74195811e951e9fbe3f8              5                276
# 3    f72acec0c134474aa129              5                215
# 4    2346df08e1939e37ed64              5                211
# ..                    ...            ...                ...
# 110  433d924a6eb8706b5ba1              5                  1
# 111  db57f1743fa154618cd2              4                 12
# 112  837b068723364c202aff              5                 16
# 113  0dda049dc7ae42af6c05              5                  9
# 114  cddb55c884fb48f86bf5              5                  4
#
#                                                   name  \
# 0    Butternut squash soup with chilli & crème fraîche
# 1                               Moroccan chickpea soup
# 2                              Broccoli & stilton soup
# 3                                     Mushroom risotto
# 4                           Spicy roasted parsnip soup
# ..                                                 ...
# 110                          Strawberry & mint granita
# 111                                          Panettone
# 112                            Zabaglione trifle slice
# 113                  Toasted marshmallow & ginger cake
# 114                          Iced hazelnut zabagliones
#
#                                                  steps meal_type       origin  \
# 0    Heat oven to 200C/180C fan/gas 6.Cut 1 peeled ...   starter      English
# 1    Heat the oil in a large saucepan, then fry the...   starter  Middle East
# 2    Heat 2 tbsp rapeseed oil in a large saucepan a...   starter      English
# 3    Put 50g dried porcini mushrooms into a large b...   starter      Italian
# 4    Heat oven to 220C/fan 200C/gas 7.In a bowl, mi...   starter      British
# ..                                                 ...       ...          ...
# 110  Put the sugar and 100ml water in a medium sauc...   dessert      Italian
# 111  Grease a panettone tin (see Tip) or a 20cm dee...   dessert      Italian
# 112  For the zabaglione cream, put the egg yolks an...   dessert      Italian
# 113  Melt the butter, sugar, treacle and syrup in a...   dessert      Italian
# 114  Put all sauce ingredients into a small pan, br...   dessert      Italian
#
#      prep_time  servings                                        description  \
# 0           65         4  Come in from the cold to a warming bowlful of ...
# 1           25         4  Try something different for vegetarians with M...
# 2           45         4  A smooth blended vegetable soup with blue chee...
# 3           30         4  Barney guides you through a step-by-step guide...
# 4           45         4  Aromatic flavours transform the ordinary parsn...
# ..         ...       ...                                                ...
# 110         20         4  This light frozen dessert is smooth and slushy...
# 111         70         6  Prove your baking skills this Christmas with a...
# 112         90         8  This dish is inspired by trifle and tiramisu, ...
# 113        130         8  Decorative Italian meringue masks a spicy, moi...
# 114         30         2  An indulgent but refreshing Italian-style dessert
#
#     difficulty                                          photo_url  \
# 0         Easy  www.bbcgoodfood.com/sites/default/files/styles...
# 1         Easy  www.bbcgoodfood.com/sites/default/files/styles...
# 2         Easy  www.bbcgoodfood.com/sites/default/files/styles...
# 3         Easy  www.bbcgoodfood.com/sites/default/files/styles...
# 4         Easy  www.bbcgoodfood.com/sites/default/files/styles...
# ..         ...                                                ...
# 110       Easy  www.bbcgoodfood.com/sites/default/files/styles...
# 111       Hard  www.bbcgoodfood.com/sites/default/files/styles...
# 112       Hard  www.bbcgoodfood.com/sites/default/files/styles...
# 113       Hard  www.bbcgoodfood.com/sites/default/files/styles...
# 114       Hard  www.bbcgoodfood.com/sites/default/files/styles...
#
#                                        ingredient_list  \
# 0    [olive oil, butter, creme fraiche, butternut s...
# 1    [olive oil, beans, chickpea, lemon, celery, co...
# 2    [sunflower oil, butter, stilton, celery, brocc...
# 3    [white wine, olive oil, butter, parmesan, riso...
# 4    [olive oil, lemon, coriander, cumin, garlic, g...
# ..                                                 ...
# 110                   [caster sugar, strawberry, mint]
# 111  [caster sugar, bread, caster sugar, icing suga...
# 112  [caster sugar, marsala wine, marsala wine, whi...
# 113  [light brown sugar, caster sugar, golden syrup...
# 114  [caster sugar, chocolate, coffee, marsala wine...
#
#                               ingredient_category_list  num_of_ingredients
# 0    [Condiment, Dairy, Dairy, Fruit, Herb and Spic...                   8
# 1    [Condiment, Dry, Dry, Fruit, Herb and Spice, H...                  10
# 2    [Condiment, Dairy, Dairy, Herb and Spice, Vege...                   9
# 3    [Beverage Alcoholic, Condiment, Dairy, Dairy, ...                  11
# 4    [Condiment, Fruit, Herb and Spice, Herb and Sp...                  11
# ..                                                 ...                 ...
# 110                    [Bakery, Fruit, Herb and Spice]                   3
# 111  [Bakery, Bakery, Bakery, Bakery, Beverage Alco...                  17
# 112  [Bakery, Beverage Alcoholic, Beverage Alcoholi...                   8
# 113  [Bakery, Bakery, Bakery, Bakery, Beverage Alco...                  16
# 114  [Bakery, Bakery, Beverage, Beverage Alcoholic,...                   8
#
# [115 rows x 15 columns]

# %%
recipes_df_joined['num_of_ingredients'].hist(bins=17)
plt.ylabel('frequency')
plt.xlabel('number of ingredients per recipe')
plt.savefig("/home/louis/Documents/number_of_ingredients_per_recipe3.png")
plt.show()

# %%
np.mean(pd.Series(recipes_df_joined['num_of_ingredients']))
# Out:
# 8.97391304347826

# %%
#collections.Counter(ingredients_df["name"])

# %%
import os
os.getcwd()
# Out:
# '/home/louis/code/gatinetlouis/KROK-Follow-Up/app'

# %%
fr=pd.Series(ingredients_df["name"]).value_counts()
wordcloud = WordCloud(background_color="black",max_words=100,random_state=21, max_font_size=60, collocations=False).generate_from_frequencies(fr)
fig=plt.figure(figsize=(12,8))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
wordcloud.to_file('/home/louis/Documents/wordcloud_ingredients_fig.png')

# %%
nb_of_recipes = recipes_df_joined.shape[0]
list_of_ingredients = list()
for i in range(nb_of_recipes):
    list_of_ingredients.append(list(set(recipes_df_joined.iloc[i,-3]))) #to add unique list of ingredients

# %%
model = Word2Vec.load("word2vec.model")

# %%
# model = Word2Vec(min_count=0,
#                      window=10,
#                      size=20,
#                      sample=6e-5, 
#                      alpha=0.3, 
#                      min_alpha=0.0007,
#                      workers=4,
#                     sg = 1)

# model.build_vocab(list_of_ingredients, progress_per=10)
# model.train(list_of_ingredients, total_examples=model.corpus_count, epochs=500, report_delay=1)
# model.init_sims(replace=True)
# model.save("word2vec.model")
print(model.wv.most_similar('chocolate'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ee87cead7511> in <module>
#      12 # model.init_sims(replace=True)
#      13 # model.save("word2vec.model")
# ---> 14 print(model.wv.most_similar('chocolate'))
#
# NameError: name 'model' is not defined

# %%
print(model.wv.most_similar('chicken legs'))
# Out:
# [('mushroom', 0.8186691999435425), ('red wine', 0.7490093111991882), ('risotto rice', 0.7398844361305237), ('sweet potato', 0.7359125018119812), ('carrots', 0.7153655290603638), ('chicken stock', 0.7146432995796204), ('fennel', 0.6753901839256287), ('chestnut', 0.6690915822982788), ('sausage', 0.6625218987464905), ('beef', 0.6560136079788208)]

# %%
print(model.wv.similarity('chicken legs','chocolate'))
# Out:
# 0.14750335

# %%
print(model.wv.similarity('coriander','cumin'))
# Out:
# 0.7451751

# %%
# ingredient_vector_dim = 20
# max_distance_ingredient = 12 # max ingredient distance to consider in a sentence 
# min_count = 0 #minimum total frequency for an ingredient
# model = Word2Vec(list_of_ingredients, size=20, window=10, min_count=1, workers=4, sg = 1, seed = 1)
# model.init_sims(replace=True)

# print(model.wv.most_similar('chocolate'))

# %%
# list(model.wv.vocab)

# %%
def annotated_plot(result,title):
    plt.scatter(result[:, 0], result[:, 1], color='orange')
    ingredients = list(model.wv.vocab)
    for i, ingredient in enumerate(ingredients):
        plt.annotate(ingredient, xy=(result[i, 0], result[i, 1]), size=7, weight='light')
    plt.title(title)
    plt.xlabel("1st component")
    plt.ylabel("2nd component")
    plt.savefig("/home/louis/Documents/annotated_plot.png")
    plt.show()

# %%
#function for plot mapped by category

def mapping_by_category_plot(result, title):
    ingredients = list(model.wv.vocab)
    categories = list()
    for ingredient in ingredients:
        category = np.array(ingredients_df.loc[ingredients_df["name"] == ingredient]["category"])[0]
        categories.append(category)

    df = pd.DataFrame({"x": result[:,0],
                      "y": result[:,1],
                      "category": categories
                      })
    
    fig, ax = plt.subplots()
    ax.set_prop_cycle(color=["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728",
                             "#9467bd", "#8c564b", "#e377c2", "#7f7f7f",
                             "#bcbd22", "#17becf","#00f455","#ff05ff",
                             "#f9cd93","#606484"])


    groups = df.groupby("category")
    for name, group in groups:
        ax.plot(
        group["x"],
        group["y"],
        marker="o",
        linestyle="",
        label=name)

    plt.title(title)
    plt.xlabel("1st component")
    plt.ylabel("2nd component")
    plt.legend(bbox_to_anchor=(1, 1))
    plt.savefig("/home/louis/Documents/category_plot.png")
    plt.show()

# %%
count_cuis = collections.Counter(recipes_df_joined["origin"])
count_ing = collections.Counter(ingredients_df["name"])
track_ingredients = dict(zip(count_cuis.keys(), [list() for x in count_cuis.keys()]))

for i in range(recipes_df_joined.shape[0]):
    ingredients = recipes_df_joined.iloc[i,-3]
    track_ingredients[recipes_df_joined.iloc[i,6]].extend(ingredients)
    
for label, tracking in track_ingredients.items():
    track_ingredients[label] = collections.Counter(tracking)
    
def return_most_popular(ing):
    origin = None
    record = 0
    for label, tracking in track_ingredients.items():
        norm_freq = float(tracking[ing]) / float(count_ing[ing])
        if norm_freq > record:
            origin = label
            record = norm_freq
            
    return origin

# %%
#function for plot mapped by most frequent origin per ingredient

def mapping_by_origin_plot(result, title):
    
    ingredients = list(model.wv.vocab)
    origins = list()
    for ingredient in ingredients:
        origin = return_most_popular(ingredient)
        origins.append(origin)

    df = pd.DataFrame({"x": result[:,0],
                      "y": result[:,1],
                      "origin": origins
                      })

    groups = df.groupby("origin")
    for name, group in groups:
        plt.plot(
        group["x"],
        group["y"],
        marker="o",
        linestyle="",
        label=name)

    plt.title(title)
    plt.xlabel("1st component")
    plt.ylabel("2nd component")
    plt.legend(bbox_to_anchor=(1, 1))
    plt.savefig("/home/louis/Documents/origin_plot.png")
    plt.show()

# %% [markdown]
# ### PCA

# %%
X = model.wv[model.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.13894774, 0.10824464], dtype=float32)

# %%
pca = PCA()
pca.fit(X)
cumsum = np.cumsum(pca.explained_variance_ratio_)
np.argmax(cumsum >= 0.95) +1
cumsum
# Out:
# array([0.13894774, 0.24719238, 0.34270567, 0.4313418 , 0.51171166,
#        0.5795323 , 0.6353347 , 0.68933177, 0.73651576, 0.78117305,
#        0.82126355, 0.8597047 , 0.89179224, 0.921319  , 0.94371927,
#        0.9638365 , 0.97837657, 0.9909642 , 0.9979894 , 1.        ],
#       dtype=float32)

# %%
annotated_plot(result, "Principal Component Analysis")

# %%
mapping_by_category_plot(result, "Principal Component Analysis")

# %%
mapping_by_origin_plot(result, "Principal Component Analysis")

# %% [markdown]
# ### LLE

# %%
X = model.wv[model.wv.vocab]
lle = LocallyLinearEmbedding(n_components=2, n_neighbors=15)
result= lle.fit_transform(X)

# %%
annotated_plot(result, "Locally Linear Embedding")

# %%
mapping_by_category_plot(result, "Locally Linear Embedding")

# %%
mapping_by_origin_plot(result, "Locally Linear Embedding")

# %% [markdown]
# ### TSNE

# %%
X = model.wv[model.wv.vocab]
tsne = TSNE(n_components=2)
result= tsne.fit_transform(X)

# %%
annotated_plot(result, "T-SNE")

# %%
mapping_by_category_plot(result, "T-SNE")

# %%
mapping_by_origin_plot(result, "T-SNE")

# %% [markdown]
# ### Recommendation

# %%
set(model.wv.index2word)
# Out:
# {'Somerset Pomona',
#  'allherb and spice',
#  'almond',
#  'anchovy',
#  'apple',
#  'apricot',
#  'artichoke',
#  'avocado',
#  'bacon',
#  'baking powder',
#  'balsamic vinegar',
#  'banana',
#  'basil',
#  'basmati rice',
#  'bay leaf',
#  'beans',
#  'beef',
#  'beef mince',
#  'beef stock',
#  'bicarbonate of soda',
#  'biscuits',
#  'bitter orange',
#  'black treacle',
#  'brandy',
#  'bread',
#  'breadcrumb',
#  'bresaola',
#  'brioche',
#  'broccoli',
#  'butter',
#  'buttermilk',
#  'butternut squash',
#  'cabbage',
#  'cajun spices',
#  'capers',
#  'cardamom',
#  'carrots',
#  'caster sugar',
#  'celeriac',
#  'celery',
#  'cheddar',
#  'cheese',
#  'cherries',
#  'cherry tomatoes',
#  'chestnut',
#  'chicken breasts',
#  'chicken legs',
#  'chicken livers',
#  'chicken stock',
#  'chicken thighs',
#  'chickpea',
#  'chicory',
#  'chili',
#  'chili flakes',
#  'chipotle paste',
#  'chive',
#  'chocolate',
#  'chorizo',
#  'cinnamon',
#  'cinnamon stick',
#  'cocoa',
#  'cocoa powder',
#  'coconut milk',
#  'coffee',
#  'common tuna',
#  'coriander',
#  'corn',
#  'courgette',
#  'crab',
#  'crayfish tails',
#  'cream',
#  'cream cheese',
#  'creme fraiche',
#  'cucumber',
#  'cumin',
#  'cured ham',
#  'curry paste',
#  'dark chocolate',
#  'demerara sugar',
#  'eggplant',
#  'eggs',
#  'fennel',
#  'fennel seeds',
#  'fish',
#  'fish sauce',
#  'flour',
#  'fontina',
#  'garam masala',
#  'garlic',
#  'gelatin',
#  'ginger',
#  'golden syrup sugar',
#  'gooseberry',
#  'grape',
#  'grapefruit',
#  'ground almond',
#  'ground cinnamon',
#  'ground coriander',
#  'ground turmeric',
#  'ham',
#  'hazelnut',
#  'honey',
#  'icing sugar',
#  'lasagne sheets',
#  'leek',
#  'lemon',
#  'lemon juice',
#  'lentils',
#  'light brown sugar',
#  'lime',
#  'marjoram',
#  'marsala wine',
#  'mascarpone',
#  'mayonnaise',
#  'melon',
#  'milk',
#  'mint',
#  'mozzarella',
#  'mushroom',
#  'mustard',
#  'nutmeg',
#  'oat bread',
#  'olive',
#  'olive oil',
#  'onion',
#  'orange',
#  'orange oil',
#  'oregano',
#  'pancetta',
#  'paprika',
#  'parmesan',
#  'parsley',
#  'parsnip',
#  'pasta',
#  'peanuts',
#  'peas',
#  'penne',
#  'pepper',
#  'pesto',
#  'pine nuts',
#  'plum',
#  'polenta',
#  'potatoes',
#  'prawns',
#  'puff pastry',
#  'pumpkin seeds',
#  'quinoa',
#  'radish',
#  'raisin',
#  'raisins',
#  'raspberry',
#  'red wine',
#  'redskin onion',
#  'rice',
#  'rice vinegar',
#  'ricotta',
#  'risotto rice',
#  'rosemary',
#  'rowanberry',
#  'rum',
#  'sage',
#  'salad',
#  'salmon',
#  'salt',
#  'sausage',
#  'self-raising flour',
#  'semolina',
#  'shallot',
#  'sherry',
#  'smoked mackerel',
#  'smoked salmon',
#  'soured cream',
#  'spaghetti',
#  'spinach',
#  'sponge finger',
#  'spring onion',
#  'stilton',
#  'strawberry',
#  'sugar',
#  'sundried tomato',
#  'sunflower oil',
#  'sweet potato',
#  'thyme',
#  'tomato',
#  'tomato paste',
#  'tomato puree',
#  'tomato sauce',
#  'vanilla',
#  'vegetable stock',
#  'vinegar',
#  'walnut',
#  'white wine',
#  'yeast',
#  'yogurt'}

# %%
index2word_set = set(model.wv.index2word)

def avg_feature_vector(recipe_array, model, num_features, index2word_set):
    ingredients = list(set(recipe_array))
    feature_vec = np.zeros((num_features, ), dtype='float32')
    n_ingredients = 0
    for ingredient in ingredients:
        if ingredient in index2word_set:
            n_ingredients += 1
            feature_vec = np.add(feature_vec, model.wv[ingredient])
    if (n_ingredients > 0):
        feature_vec = np.divide(feature_vec, n_ingredients)
    return feature_vec

# %%
#similarity score between first 2 recipes

r1_afv = avg_feature_vector(list_of_ingredients[0], model=model, num_features=20, index2word_set=index2word_set)
r2_afv = avg_feature_vector(list_of_ingredients[1], model=model, num_features=20, index2word_set=index2word_set)

sim = 1 - spatial.distance.cosine(r1_afv, r2_afv)

print(sim)
# Out:
# 0.8128452301025391

# %%
#best recommendation for the 1st recipe

afv_list = list()
for i in range(len(list_of_ingredients)):
    afv = avg_feature_vector(list_of_ingredients[i], model=model, num_features=20, index2word_set=index2word_set)
    afv_list.append(afv)
    
similarity_score = list()
for i in range(len(list_of_ingredients)):
    sim = 1 - spatial.distance.cosine(afv_list[0], afv_list[i])
    similarity_score.append(sim)

index = np.argsort(similarity_score)[-2]
print(list_of_ingredients[index], list_of_ingredients[0])
# Out:
# ['garlic', 'vegetable stock', 'tomato sauce', 'rice', 'onion', 'pepper', 'coriander', 'cumin', 'olive oil'] ['garlic', 'vegetable stock', 'onion', 'creme fraiche', 'butternut squash', 'chili', 'butter', 'olive oil']

# %%
def recommended_recipe(ingredients_for_one_recipe, ingredients_for_all_recipes):

    afv_list = list()
    similarity_score = list()
    afv_recipe = avg_feature_vector(ingredients_for_one_recipe, model=model, num_features=20, index2word_set=index2word_set)
    
    for i in range(len(ingredients_for_all_recipes)):
        afv = avg_feature_vector(ingredients_for_all_recipes[i], model=model, num_features=20, index2word_set=index2word_set)
        afv_list.append(afv)
        sim = 1 - spatial.distance.cosine(afv_recipe, afv_list[i])
        similarity_score.append(sim)

    index = np.argsort(similarity_score)[-2]
    return list_of_ingredients[index], index

# %%
def recommended_recipe_second(ingredients_for_one_recipe, ingredients_for_all_recipes):

    afv_list = list()
    similarity_score = list()
    afv_recipe = avg_feature_vector(ingredients_for_one_recipe, model=model, num_features=20, index2word_set=index2word_set)

    for i in range(len(ingredients_for_all_recipes)):
        afv = avg_feature_vector(ingredients_for_all_recipes[i], model=model, num_features=20, index2word_set=index2word_set)
        afv_list.append(afv)
        sim = 1 - spatial.distance.cosine(afv_recipe, afv_list[i])
        similarity_score.append(sim)

    index = np.argsort(similarity_score)[-3]
    return list_of_ingredients[index], index

# %%
def find_index_with_recipe_name(recipe_name):
    true_false = recipes_df_joined[["name"]] == recipe_name
    index = np.where(true_false)[0][0]
    return index

# %%
def recommender(recipe_name):
    index = find_index_with_recipe_name(recipe_name)
    ingredients_recipe = list_of_ingredients[index]
    ingredients_reco, index_new = recommended_recipe(ingredients_recipe, list_of_ingredients)
    ingredients_reco_second, index_new_second = recommended_recipe_second(ingredients_recipe, list_of_ingredients)
    recipe = recipes_df_joined.iloc[index,3]
    reco = recipes_df_joined.iloc[index_new,3]
    reco_second = recipes_df_joined.iloc[index_new_second,3]
    both_recos = [reco,reco_second]
    print("current recipe", recipe, ingredients_recipe)
    print("                   ")
    print("recommended recipe 1:", reco, ingredients_reco)
    print("                   ")
    print("recommended recipe 2:", reco_second, ingredients_reco_second)
    return both_recos

# %%
print(recommender("Mushroom soup"))
# Out:
# current recipe Mushroom soup ['garlic', 'chicken stock', 'flour', 'parsley', 'cream', 'bay leaf', 'onion', 'butter', 'mushroom']
#
# recommended recipe 1: One-pot chicken chasseur ['garlic', 'chicken stock', 'thyme', 'chicken legs', 'red wine', 'tomato sauce', 'onion', 'butter', 'mushroom', 'olive oil']
#
# recommended recipe 2: Mushroom risotto ['garlic', 'butter', 'parmesan', 'parsley', 'vegetable stock', 'onion', 'white wine', 'risotto rice', 'mushroom', 'olive oil']
# ['One-pot chicken chasseur', 'Mushroom risotto']

# %%
print(recommender("Best ever chunky guacamole"))
# Out:
# current recipe Best ever chunky guacamole ['coriander', 'avocado', 'tomato', 'chili', 'lime', 'onion']
#
# recommended recipe 1: Mexican bean soup with guacamole ['coriander', 'avocado', 'beans', 'cumin', 'garlic', 'tomato', 'vegetable stock', 'chili', 'sunflower oil', 'pepper', 'lime', 'onion']
#
# recommended recipe 2: Mexican penne with avocado ['corn', 'coriander', 'avocado', 'garlic', 'cumin', 'tomato', 'vegetable stock', 'chili', 'penne', 'sunflower oil', 'pepper', 'lime', 'onion']
# ['Mexican bean soup with guacamole', 'Mexican penne with avocado']

# %%
print(recommender("Best ever chocolate brownies recipe"))
# Out:
# current recipe Best ever chocolate brownies recipe ['butter', 'cocoa powder', 'caster sugar', 'dark chocolate', 'eggs', 'chocolate', 'flour']
#
# recommended recipe 1: Chocolate brownie cake ['butter', 'vanilla', 'cocoa powder', 'caster sugar', 'light brown sugar', 'golden syrup sugar', 'eggs', 'chocolate', 'baking powder', 'flour']
#
# recommended recipe 2: Iced hazelnut zabagliones ['caster sugar', 'cream', 'eggs', 'hazelnut', 'marsala wine', 'chocolate', 'coffee']
# ['Chocolate brownie cake', 'Iced hazelnut zabagliones']

# %%
print(recommender("Home-style chicken curry"))
# Out:
# current recipe Home-style chicken curry ['garam masala', 'ground turmeric', 'caster sugar', 'coriander', 'tomato', 'fennel seeds', 'cinnamon stick', 'cumin', 'garlic', 'chili flakes', 'chicken stock', 'sunflower oil', 'ginger', 'onion', 'chicken thighs']
#
# recommended recipe 1: Mexican chicken stew ['caster sugar', 'coriander', 'tomato', 'garlic', 'sunflower oil', 'chicken breasts', 'chipotle paste', 'onion']
#
# recommended recipe 2: Spicy roasted parsnip soup ['ground turmeric', 'coriander', 'tomato', 'garlic', 'lemon', 'cumin', 'mustard', 'vegetable stock', 'parsnip', 'olive oil', 'onion']
# ['Mexican chicken stew', 'Spicy roasted parsnip soup']

# %% [markdown]
# Good examples

# %%
recommender("Mozzarella peppers with chunky Italian dressing");
# Out:
# current recipe Mozzarella peppers with chunky Italian dressing ['olive', 'tomato', 'anchovy', 'balsamic vinegar', 'mozzarella', 'pepper', 'basil']
#
# recommended recipe 1: Tomato bruschetta ['bread', 'redskin onion', 'tomato', 'garlic', 'balsamic vinegar', 'basil', 'olive oil']
#
# recommended recipe 2: Italian-style stuffed aubergines ['cherry tomatoes', 'garlic', 'mozzarella', 'basil', 'olive', 'breadcrumb', 'olive oil', 'onion', 'eggplant']

# %%
recommender("Best ever chocolate brownies recipe");
# Out:
# current recipe Best ever chocolate brownies recipe ['butter', 'cocoa powder', 'caster sugar', 'dark chocolate', 'eggs', 'chocolate', 'flour']
#
# recommended recipe 1: Chocolate brownie cake ['butter', 'vanilla', 'cocoa powder', 'caster sugar', 'light brown sugar', 'golden syrup sugar', 'eggs', 'chocolate', 'baking powder', 'flour']
#
# recommended recipe 2: Iced hazelnut zabagliones ['caster sugar', 'cream', 'eggs', 'hazelnut', 'marsala wine', 'chocolate', 'coffee']

# %%
recommender("Best ever chunky guacamole");
# Out:
# current recipe Best ever chunky guacamole ['coriander', 'avocado', 'tomato', 'chili', 'lime', 'onion']
#
# recommended recipe 1: Mexican bean soup with guacamole ['coriander', 'avocado', 'beans', 'cumin', 'garlic', 'tomato', 'vegetable stock', 'chili', 'sunflower oil', 'pepper', 'lime', 'onion']
#
# recommended recipe 2: Mexican penne with avocado ['corn', 'coriander', 'avocado', 'garlic', 'cumin', 'tomato', 'vegetable stock', 'chili', 'penne', 'sunflower oil', 'pepper', 'lime', 'onion']

# %% [markdown]
# Python in rails

# %%
import sys
import pandas as pd
import numpy as np
import collections
from gensim.models import Word2Vec
from scipy import spatial

#variables from Ruby
current_recipe_id = sys.argv[1]
current_recipe_name = sys.argv[2]

#data pre-processing
ingredients_df = pd.read_csv('db/datas/ingredients.csv', sep=";")
recipes_df = pd.read_csv('db/datas/recipes_new.csv',sep=";")
ingredients_by_recipe = ingredients_df[["uuid", "name"]].groupby(['uuid']).agg({'name':lambda x: list(x)})
ingredients_by_recipe["ingredient_category_list"] = ingredients_df[["uuid", "category"]].groupby(['uuid']).agg({'category': lambda y: list(y)})
ingredients_by_recipe["num_of_ingredients"] = ingredients_df[["uuid", "name"]].groupby(['uuid']).size()
ingredients_by_recipe.columns = ["ingredient_list","ingredient_category_list","num_of_ingredients"]
recipes_df_joined = pd.merge(recipes_df, ingredients_by_recipe, on='uuid')

#modeling
nb_of_recipes = recipes_df_joined.shape[0]
list_of_ingredients = list()
for i in range(nb_of_recipes):
    list_of_ingredients.append(list(set(recipes_df_joined.iloc[i,-3]))) #to add unique list of ingredients
model = Word2Vec.load("app/word2vec.model")

#We don't redo the following code as we already loaded our trained model
# model = Word2Vec(min_count=0,
#                      window=10,
#                      size=20,
#                      sample=6e-5,
#                      alpha=0.3,
#                      min_alpha=0.0007,
#                      workers=4,
#                     sg = 1)

# model.build_vocab(list_of_ingredients, progress_per=10)
# model.train(list_of_ingredients, total_examples=model.corpus_count, epochs=500, report_delay=1)
# model.init_sims(replace=True)
# model.save("word2vec.model")

index2word_set = set(model.wv.index2word)

def avg_feature_vector(recipe_array, model, num_features, index2word_set):
    ingredients = list(set(recipe_array))
    feature_vec = np.zeros((num_features, ), dtype='float32')
    n_ingredients = 0
    for ingredient in ingredients:
        if ingredient in index2word_set:
            n_ingredients += 1
            feature_vec = np.add(feature_vec, model.wv[ingredient])
    if (n_ingredients > 0):
        feature_vec = np.divide(feature_vec, n_ingredients)
    return feature_vec

def recommended_recipe(ingredients_for_one_recipe, ingredients_for_all_recipes):

    afv_list = list()
    similarity_score = list()
    afv_recipe = avg_feature_vector(ingredients_for_one_recipe, model=model, num_features=20, index2word_set=index2word_set)

    for i in range(len(ingredients_for_all_recipes)):
        afv = avg_feature_vector(ingredients_for_all_recipes[i], model=model, num_features=20, index2word_set=index2word_set)
        afv_list.append(afv)
        sim = 1 - spatial.distance.cosine(afv_recipe, afv_list[i])
        similarity_score.append(sim)

    index = np.argsort(similarity_score)[-2]
    return list_of_ingredients[index], index

def recommended_recipe_second(ingredients_for_one_recipe, ingredients_for_all_recipes):

    afv_list = list()
    similarity_score = list()
    afv_recipe = avg_feature_vector(ingredients_for_one_recipe, model=model, num_features=20, index2word_set=index2word_set)

    for i in range(len(ingredients_for_all_recipes)):
        afv = avg_feature_vector(ingredients_for_all_recipes[i], model=model, num_features=20, index2word_set=index2word_set)
        afv_list.append(afv)
        sim = 1 - spatial.distance.cosine(afv_recipe, afv_list[i])
        similarity_score.append(sim)

    index = np.argsort(similarity_score)[-3]
    return list_of_ingredients[index], index

def find_index_with_recipe_name(recipe_name):
    true_false = recipes_df_joined[["name"]] == recipe_name
    index = np.where(true_false)[0][0]
    return index

def recommender(recipe_name):
    index = find_index_with_recipe_name(recipe_name)
    ingredients_recipe = list_of_ingredients[index]
    ingredients_reco, index_new = recommended_recipe(ingredients_recipe, list_of_ingredients)
    ingredients_reco_second, index_new_second = recommended_recipe_second(ingredients_recipe, list_of_ingredients)
    recipe = recipes_df_joined.iloc[index,3]
    reco = recipes_df_joined.iloc[index_new,3]
    reco_second = recipes_df_joined.iloc[index_new_second,3]
    both_recos = [reco,reco_second]
    # print("current recipe", recipe, ingredients_recipe)
    # print("                   ")
    # print("recommended recipe 1:", reco, ingredients_reco)
    # print("                   ")
    # print("recommended recipe 2:", reco_second, ingredients_reco_second)
    return both_recos

print(recommender(current_recipe_name))

# %%
model.wv.vocab
# Out:
# {'butter': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64090>,
#  'butternut squash': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64150>,
#  'garlic': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64250>,
#  'chili': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c642d0>,
#  'onion': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64350>,
#  'vegetable stock': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c643d0>,
#  'olive oil': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64410>,
#  'creme fraiche': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64450>,
#  'beans': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64310>,
#  'cumin': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64390>,
#  'coriander': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64490>,
#  'tomato': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c644d0>,
#  'celery': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64510>,
#  'chickpea': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64550>,
#  'lemon': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64590>,
#  'broccoli': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c645d0>,
#  'leek': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64610>,
#  'stilton': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64650>,
#  'potatoes': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64690>,
#  'sunflower oil': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c646d0>,
#  'white wine': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64710>,
#  'parsley': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64750>,
#  'mushroom': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64790>,
#  'parmesan': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c647d0>,
#  'risotto rice': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64810>,
#  'mustard': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64850>,
#  'parsnip': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64890>,
#  'ground turmeric': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c648d0>,
#  'cream': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64910>,
#  'pumpkin seeds': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64950>,
#  'salad': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64990>,
#  'prawns': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c649d0>,
#  'honey': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64a10>,
#  'ginger': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64a50>,
#  'lime': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64a90>,
#  'smoked salmon': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64ad0>,
#  'flour': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64b10>,
#  'smoked mackerel': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64b50>,
#  'eggs': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64b90>,
#  'spaghetti': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64bd0>,
#  'carrots': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64c10>,
#  'cabbage': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64c50>,
#  'tomato sauce': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64c90>,
#  'peanuts': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64cd0>,
#  'cucumber': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64d10>,
#  'shallot': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64d50>,
#  'mint': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64d90>,
#  'fish sauce': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64dd0>,
#  'caster sugar': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64e10>,
#  'rice vinegar': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64e50>,
#  'chili flakes': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64e90>,
#  'sugar': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64ed0>,
#  'avocado': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64f10>,
#  'chicken stock': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64f50>,
#  'bay leaf': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64f90>,
#  'apple': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c64fd0>,
#  'thyme': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65050>,
#  'brioche': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65090>,
#  'chicken livers': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c650d0>,
#  'crayfish tails': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65110>,
#  'chicory': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65150>,
#  'pepper': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65190>,
#  'cheese': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c651d0>,
#  'pasta': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65210>,
#  'chicken breasts': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65250>,
#  'cajun spices': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65290>,
#  'chorizo': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c652d0>,
#  'rice': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65310>,
#  'lentils': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65350>,
#  'curry paste': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65390>,
#  'yogurt': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c653d0>,
#  'cherry tomatoes': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65410>,
#  'pesto': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65450>,
#  'basil': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65490>,
#  'ground coriander': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c654d0>,
#  'bacon': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65510>,
#  'cheddar': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65550>,
#  'mozzarella': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65590>,
#  'basmati rice': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c655d0>,
#  'cardamom': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65610>,
#  'raisins': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65650>,
#  'cinnamon stick': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65690>,
#  'courgette': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c656d0>,
#  'lasagne sheets': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65710>,
#  'ricotta': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65750>,
#  'sweet potato': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65790>,
#  'red wine': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c657d0>,
#  'beef stock': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65810>,
#  'beef mince': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65850>,
#  'nutmeg': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65890>,
#  'milk': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c658d0>,
#  'fennel seeds': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65910>,
#  'garam masala': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65950>,
#  'chicken thighs': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65990>,
#  'oregano': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c659d0>,
#  'rosemary': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65a10>,
#  'chicken legs': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65a50>,
#  'coconut milk': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65a90>,
#  'peas': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65ad0>,
#  'cocoa powder': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65b10>,
#  'dark chocolate': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65b50>,
#  'chocolate': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65b90>,
#  'self-raising flour': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65bd0>,
#  'banana': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65c10>,
#  'baking powder': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65c50>,
#  'raspberry': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65c90>,
#  'ground almond': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65cd0>,
#  'vanilla': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65d10>,
#  'Somerset Pomona': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65d50>,
#  'cherries': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65d90>,
#  'mascarpone': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65dd0>,
#  'light brown sugar': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65e10>,
#  'walnut': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65e50>,
#  'golden syrup sugar': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65e90>,
#  'cream cheese': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65ed0>,
#  'soured cream': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65f10>,
#  'biscuits': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65f50>,
#  'melon': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65f90>,
#  'strawberry': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c65fd0>,
#  'hazelnut': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a050>,
#  'demerara sugar': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a090>,
#  'ground cinnamon': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a0d0>,
#  'puff pastry': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a110>,
#  'gooseberry': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a150>,
#  'plum': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a190>,
#  'orange': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a1d0>,
#  'corn': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a210>,
#  'paprika': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a250>,
#  'sage': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a290>,
#  'celeriac': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a2d0>,
#  'buttermilk': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a310>,
#  'yeast': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a350>,
#  'mayonnaise': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a390>,
#  'chipotle paste': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a3d0>,
#  'penne': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a410>,
#  'cinnamon': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a450>,
#  'beef': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a490>,
#  'quinoa': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a4d0>,
#  'olive': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a510>,
#  'balsamic vinegar': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a550>,
#  'anchovy': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a590>,
#  'bitter orange': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a5d0>,
#  'chive': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a610>,
#  'crab': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a650>,
#  'oat bread': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a690>,
#  'grapefruit': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a6d0>,
#  'vinegar': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a710>,
#  'bread': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a750>,
#  'redskin onion': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a790>,
#  'grape': <gensim.models.keyedvectors.Vocab at 0x7f3fabeb9390>,
#  'salt': <gensim.models.keyedvectors.Vocab at 0x7f3fabeb9e50>,
#  'semolina': <gensim.models.keyedvectors.Vocab at 0x7f3fabeb98d0>,
#  'radish': <gensim.models.keyedvectors.Vocab at 0x7f3fabeb9810>,
#  'fontina': <gensim.models.keyedvectors.Vocab at 0x7f3fabeb9cd0>,
#  'cured ham': <gensim.models.keyedvectors.Vocab at 0x7f3fabeb92d0>,
#  'artichoke': <gensim.models.keyedvectors.Vocab at 0x7f3fd8939e90>,
#  'bresaola': <gensim.models.keyedvectors.Vocab at 0x7f3fab80e590>,
#  'capers': <gensim.models.keyedvectors.Vocab at 0x7f3fabea4150>,
#  'almond': <gensim.models.keyedvectors.Vocab at 0x7f3fabea43d0>,
#  'lemon juice': <gensim.models.keyedvectors.Vocab at 0x7f3fabddd090>,
#  'pancetta': <gensim.models.keyedvectors.Vocab at 0x7f3fabddd290>,
#  'breadcrumb': <gensim.models.keyedvectors.Vocab at 0x7f3fabddd310>,
#  'tomato puree': <gensim.models.keyedvectors.Vocab at 0x7f3fabddd590>,
#  'sundried tomato': <gensim.models.keyedvectors.Vocab at 0x7f3fabddd110>,
#  'ham': <gensim.models.keyedvectors.Vocab at 0x7f3fabdddc10>,
#  'salmon': <gensim.models.keyedvectors.Vocab at 0x7f3fabddded0>,
#  'allherb and spice': <gensim.models.keyedvectors.Vocab at 0x7f3fabec06d0>,
#  'tomato paste': <gensim.models.keyedvectors.Vocab at 0x7f3fabec05d0>,
#  'common tuna': <gensim.models.keyedvectors.Vocab at 0x7f3fabec0c50>,
#  'spring onion': <gensim.models.keyedvectors.Vocab at 0x7f3fabec0090>,
#  'pine nuts': <gensim.models.keyedvectors.Vocab at 0x7f3fabec0b10>,
#  'fennel': <gensim.models.keyedvectors.Vocab at 0x7f3fabec0f90>,
#  'chestnut': <gensim.models.keyedvectors.Vocab at 0x7f3fabdf7c90>,
#  'sausage': <gensim.models.keyedvectors.Vocab at 0x7f3fabdf7fd0>,
#  'polenta': <gensim.models.keyedvectors.Vocab at 0x7f3fabe39950>,
#  'rowanberry': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a7d0>,
#  'marjoram': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a810>,
#  'eggplant': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a850>,
#  'spinach': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a890>,
#  'fish': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a8d0>,
#  'orange oil': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a910>,
#  'apricot': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a950>,
#  'cocoa': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a990>,
#  'coffee': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6a9d0>,
#  'marsala wine': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6aa10>,
#  'brandy': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6aa50>,
#  'sponge finger': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6aa90>,
#  'icing sugar': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6aad0>,
#  'sherry': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6ab10>,
#  'gelatin': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6ab50>,
#  'rum': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6ab90>,
#  'raisin': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6abd0>,
#  'black treacle': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6ac10>,
#  'bicarbonate of soda': <gensim.models.keyedvectors.Vocab at 0x7f3fa9c6ac50>}

# %% [markdown]
# ### OTHER MODEL

# %%
model2 = Word2Vec.load("word2vec2.model")

# %%
# model2 = Word2Vec(min_count=0,
#                      window=19,
#                      size=20,
#                      sample=6e-5, 
#                      alpha=0.3, 
#                      min_alpha=0.0001,
#                      workers=4,
#                     sg = 1)

# model2.build_vocab(list_of_ingredients, progress_per=10)
# model2.train(list_of_ingredients, total_examples=model2.corpus_count, epochs=500, report_delay=1)
# model2.init_sims(replace=True)
# model2.save("word2vec3.model")

# %%
print(model2.wv.most_similar('chocolate'))
# Out:
# [('coffee', 0.8954735398292542), ('cocoa', 0.8851733207702637), ('marsala wine', 0.8816825151443481), ('hazelnut', 0.8249636292457581), ('sponge finger', 0.819452166557312), ('dark chocolate', 0.8143340349197388), ('cocoa powder', 0.7956286072731018), ('brandy', 0.7840530276298523), ('biscuits', 0.7643678784370422), ('vanilla', 0.7426465749740601)]

# %%
print(model2.wv.most_similar('chicken legs'))
# Out:
# [('risotto rice', 0.7544093728065491), ('bay leaf', 0.7469637393951416), ('carrots', 0.7165610790252686), ('beef mince', 0.7110880613327026), ('red wine', 0.6822173595428467), ('mushroom', 0.6804685592651367), ('sausage', 0.6716536283493042), ('onion', 0.6676063537597656), ('pancetta', 0.6605663299560547), ('fennel', 0.6533814668655396)]

# %%
print(model2.wv.similarity('chicken legs','chocolate'))
# Out:
# 0.32197052

# %%
print(model2.wv.similarity('coriander','cumin'))
# Out:
# 0.683406

# %%
model2.wv.similar_by_word('basil', topn=6)
# Out:
# [('bacon', 0.703833818435669),
#  ('anchovy', 0.6816688776016235),
#  ('capers', 0.6803358793258667),
#  ('white wine', 0.6572622656822205),
#  ('olive', 0.6562613844871521),
#  ('mozzarella', 0.6561096906661987)]

# %%
model2.wv.similarity('beef stock','beef')
# Out:
# 0.7528529

# %%
print(model2.wv.similarity('chocolate','dark chocolate'))
# Out:
# 0.81433415

# %%
print(model2.wv.similarity('chocolate','coffee'))
# Out:
# 0.8954736

# %%
print(model2.wv.similarity('sugar','caster sugar'))
# Out:
# 0.6170152

# %%
model2.wv.similarity('tomato','raisin')
# Out:
# 0.018335685

# %%
model2.wv.similar_by_word('caster sugar', topn=6)
# Out:
# [('vanilla', 0.7250760793685913),
#  ('eggs', 0.6808465719223022),
#  ('light brown sugar', 0.662726879119873),
#  ('gelatin', 0.6405803561210632),
#  ('bicarbonate of soda', 0.6319674253463745),
#  ('icing sugar', 0.6311501264572144)]

# %%
model2.wv.most_similar_cosmul(positive=['basil','olive', 'parmesan', 'garlic'], negative=None, topn=10)
# Out:
# [('artichoke', 0.4291188418865204),
#  ('bresaola', 0.4145168364048004),
#  ('olive oil', 0.39586177468299866),
#  ('rosemary', 0.3814605474472046),
#  ('bacon', 0.3693040907382965),
#  ('fish', 0.3591812252998352),
#  ('fennel', 0.336062490940094),
#  ('tomato puree', 0.33042457699775696),
#  ('spring onion', 0.32898813486099243),
#  ('eggplant', 0.32798492908477783)]

# %%
model2.wv.most_similar_cosmul(positive=['milk', 'baking powder'],topn=6)
# Out:
# [('light brown sugar', 0.6892565488815308),
#  ('buttermilk', 0.6862180829048157),
#  ('golden syrup sugar', 0.6805030703544617),
#  ('cocoa powder', 0.6731640696525574),
#  ('gooseberry', 0.6696959733963013),
#  ('flour', 0.6694340705871582)]

# %%
model2.wv.similar_by_word('chocolate', topn=6)
# Out:
# [('coffee', 0.8954735398292542),
#  ('cocoa', 0.8851733207702637),
#  ('marsala wine', 0.8816825151443481),
#  ('hazelnut', 0.8249636292457581),
#  ('sponge finger', 0.819452166557312),
#  ('dark chocolate', 0.8143340349197388)]

# %%
model2.wv.similar_by_word('tomato', topn=194)
# Out:
# [('rice', 0.7518491148948669),
#  ('cumin', 0.7145986557006836),
#  ('chicken stock', 0.7049884796142578),
#  ('carrots', 0.7026181221008301),
#  ('cajun spices', 0.6933658719062805),
#  ('beans', 0.6725177764892578),
#  ('onion', 0.645812451839447),
#  ('celery', 0.6446454524993896),
#  ('pepper', 0.6357165575027466),
#  ('chicken thighs', 0.6284530162811279),
#  ('garlic', 0.619925320148468),
#  ('coriander', 0.6141916513442993),
#  ('bacon', 0.6107456684112549),
#  ('ground turmeric', 0.6097522377967834),
#  ('chorizo', 0.6072288751602173),
#  ('sweet potato', 0.6019573211669922),
#  ('parsnip', 0.5803447961807251),
#  ('beef stock', 0.5797516107559204),
#  ('bay leaf', 0.5795878171920776),
#  ('cabbage', 0.5780109763145447),
#  ('chicken breasts', 0.5754777789115906),
#  ('lentils', 0.5747215747833252),
#  ('quinoa', 0.5732979774475098),
#  ('avocado', 0.5646529793739319),
#  ('pesto', 0.5583117008209229),
#  ('garam masala', 0.5538405776023865),
#  ('coconut milk', 0.5303323268890381),
#  ('sunflower oil', 0.5273250937461853),
#  ('beef mince', 0.5261750221252441),
#  ('cinnamon stick', 0.5216832756996155),
#  ('rosemary', 0.5172600746154785),
#  ('mozzarella', 0.5156797766685486),
#  ('potatoes', 0.5033096671104431),
#  ('balsamic vinegar', 0.5023298859596252),
#  ('redskin onion', 0.49903377890586853),
#  ('olive oil', 0.4899922013282776),
#  ('curry paste', 0.48698773980140686),
#  ('chicory', 0.4842643141746521),
#  ('allherb and spice', 0.48345887660980225),
#  ('brioche', 0.47974735498428345),
#  ('fennel seeds', 0.4784619212150574),
#  ('corn', 0.4758760333061218),
#  ('chickpea', 0.47546690702438354),
#  ('basmati rice', 0.47023481130599976),
#  ('cardamom', 0.46179312467575073),
#  ('chili', 0.45997992157936096),
#  ('chipotle paste', 0.4577597379684448),
#  ('thyme', 0.45593029260635376),
#  ('chicken legs', 0.45551809668540955),
#  ('tomato sauce', 0.4529491364955902),
#  ('vegetable stock', 0.43831369280815125),
#  ('fontina', 0.4315410554409027),
#  ('paprika', 0.4302728474140167),
#  ('beef', 0.4252200126647949),
#  ('stilton', 0.4203658401966095),
#  ('penne', 0.41313278675079346),
#  ('artichoke', 0.41030219197273254),
#  ('basil', 0.40772587060928345),
#  ('sausage', 0.4053182303905487),
#  ('mushroom', 0.405187726020813),
#  ('pasta', 0.3992447853088379),
#  ('crayfish tails', 0.3990965783596039),
#  ('chili flakes', 0.3952077627182007),
#  ('bresaola', 0.3937239646911621),
#  ('cheddar', 0.3873377740383148),
#  ('ham', 0.3847854435443878),
#  ('cheese', 0.3810066282749176),
#  ('anchovy', 0.37485814094543457),
#  ('peas', 0.3731533885002136),
#  ('olive', 0.3716418743133545),
#  ('fennel', 0.36689960956573486),
#  ('oregano', 0.36688119173049927),
#  ('grape', 0.36567461490631104),
#  ('lime', 0.359719455242157),
#  ('chicken livers', 0.34980231523513794),
#  ('parmesan', 0.3492327928543091),
#  ('parsley', 0.34728485345840454),
#  ('ground coriander', 0.34166932106018066),
#  ('yogurt', 0.34165769815444946),
#  ('chestnut', 0.3383448123931885),
#  ('oat bread', 0.3374316096305847),
#  ('radish', 0.3349757194519043),
#  ('lasagne sheets', 0.3342605233192444),
#  ('red wine', 0.33306992053985596),
#  ('butternut squash', 0.3258771300315857),
#  ('cherry tomatoes', 0.3210260272026062),
#  ('leek', 0.31394389271736145),
#  ('broccoli', 0.31267648935317993),
#  ('pumpkin seeds', 0.3116229772567749),
#  ('tomato puree', 0.3056322932243347),
#  ('soured cream', 0.2993461489677429),
#  ('bread', 0.2993384599685669),
#  ('risotto rice', 0.29243484139442444),
#  ('fish sauce', 0.2915213704109192),
#  ('shallot', 0.28777068853378296),
#  ('mayonnaise', 0.28774237632751465),
#  ('walnut', 0.2822639048099518),
#  ('orange oil', 0.27979230880737305),
#  ('spinach', 0.27929723262786865),
#  ('sundried tomato', 0.2773951292037964),
#  ('rice vinegar', 0.27161312103271484),
#  ('vinegar', 0.27156150341033936),
#  ('raisins', 0.26817357540130615),
#  ('grapefruit', 0.26508575677871704),
#  ('celeriac', 0.26290810108184814),
#  ('spaghetti', 0.2625332176685333),
#  ('cucumber', 0.2612626254558563),
#  ('cured ham', 0.25844621658325195),
#  ('creme fraiche', 0.2538926601409912),
#  ('salt', 0.246529683470726),
#  ('mustard', 0.24565890431404114),
#  ('rowanberry', 0.24037222564220428),
#  ('ginger', 0.23244264721870422),
#  ('chive', 0.2284260392189026),
#  ('salmon', 0.22557783126831055),
#  ('eggplant', 0.22464343905448914),
#  ('fish', 0.2205105423927307),
#  ('lemon juice', 0.220073863863945),
#  ('milk', 0.21867775917053223),
#  ('semolina', 0.2156858742237091),
#  ('capers', 0.21343857049942017),
#  ('sage', 0.21005576848983765),
#  ('prawns', 0.20931561291217804),
#  ('cinnamon', 0.20235343277454376),
#  ('bitter orange', 0.20006021857261658),
#  ('crab', 0.1967625766992569),
#  ('breadcrumb', 0.19427311420440674),
#  ('peanuts', 0.19426855444908142),
#  ('marsala wine', 0.18240371346473694),
#  ('polenta', 0.1809394210577011),
#  ('pancetta', 0.179938405752182),
#  ('apricot', 0.17341434955596924),
#  ('buttermilk', 0.16316094994544983),
#  ('salad', 0.1572725921869278),
#  ('mascarpone', 0.15326982736587524),
#  ('mint', 0.15316824615001678),
#  ('butter', 0.15211734175682068),
#  ('marjoram', 0.15017755329608917),
#  ('brandy', 0.14750653505325317),
#  ('nutmeg', 0.14579668641090393),
#  ('honey', 0.14268286526203156),
#  ('cocoa', 0.14254224300384521),
#  ('sponge finger', 0.14150334894657135),
#  ('apple', 0.1391436755657196),
#  ('eggs', 0.12136146426200867),
#  ('courgette', 0.12068302929401398),
#  ('spring onion', 0.11837213486433029),
#  ('white wine', 0.11510861665010452),
#  ('flour', 0.11382175981998444),
#  ('Somerset Pomona', 0.11305826902389526),
#  ('banana', 0.10837256163358688),
#  ('strawberry', 0.10518309473991394),
#  ('coffee', 0.10193387418985367),
#  ('common tuna', 0.09828169643878937),
#  ('dark chocolate', 0.09555435925722122),
#  ('black treacle', 0.09360800683498383),
#  ('light brown sugar', 0.08860982954502106),
#  ('biscuits', 0.0830034464597702),
#  ('plum', 0.0828932523727417),
#  ('smoked salmon', 0.07870832085609436),
#  ('bicarbonate of soda', 0.07618869841098785),
#  ('lemon', 0.07219498604536057),
#  ('almond', 0.06944788247346878),
#  ('gooseberry', 0.06585685908794403),
#  ('chocolate', 0.06387001276016235),
#  ('ricotta', 0.06055210530757904),
#  ('tomato paste', 0.06032700836658478),
#  ('melon', 0.05766499042510986),
#  ('golden syrup sugar', 0.050990354269742966),
#  ('hazelnut', 0.05001060292124748),
#  ('yeast', 0.04477517306804657),
#  ('smoked mackerel', 0.04459569603204727),
#  ('pine nuts', 0.02702537178993225),
#  ('raisin', 0.018335700035095215),
#  ('ground cinnamon', 0.017534971237182617),
#  ('demerara sugar', 0.013499967753887177),
#  ('puff pastry', -0.0003249943256378174),
#  ('rum', -0.0013651549816131592),
#  ('baking powder', -0.0051987022161483765),
#  ('sherry', -0.016177453100681305),
#  ('ground almond', -0.02127206325531006),
#  ('cocoa powder', -0.030617475509643555),
#  ('self-raising flour', -0.04103250801563263),
#  ('vanilla', -0.04516147822141647),
#  ('icing sugar', -0.048352841287851334),
#  ('cream cheese', -0.06485201418399811),
#  ('cream', -0.06496802717447281),
#  ('raspberry', -0.06653861701488495),
#  ('orange', -0.06678837537765503),
#  ('sugar', -0.07147793471813202),
#  ('gelatin', -0.10036759823560715),
#  ('cherries', -0.12036493420600891),
#  ('caster sugar', -0.123663991689682)]

# %% [markdown]
# ### PCA

# %%
X = model2.wv[model2.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)

# %%
result.shape
# Out:
# (194, 2)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.13925059, 0.11031816], dtype=float32)

# %%
pca = PCA()
pca.fit(X)
cumsum = np.cumsum(pca.explained_variance_ratio_)
np.argmax(cumsum >= 0.95) +1
# Out:
# 16

# %%
cumsum
# Out:
# array([0.13925059, 0.24956876, 0.34819138, 0.43287635, 0.50420165,
#        0.5725705 , 0.6398162 , 0.6904918 , 0.73997915, 0.78366154,
#        0.8237721 , 0.8617725 , 0.8904998 , 0.91484493, 0.9382678 ,
#        0.9551594 , 0.9712509 , 0.98561716, 0.99759996, 1.        ],
#       dtype=float32)

# %%
annotated_plot(result, "Principal Component Analysis")

# %%
mapping_by_category_plot(result, "Principal Component Analysis")

# %%
mapping_by_origin_plot(result, "Principal Component Analysis")

# %% [markdown]
# ### LLE

# %%
X = model2.wv[model2.wv.vocab]
lle = LocallyLinearEmbedding(n_components=2, n_neighbors=15)
result= lle.fit_transform(X)

# %%
annotated_plot(result, "Locally Linear Embedding")

# %%
mapping_by_category_plot(result, "Locally Linear Embedding")

# %%
mapping_by_origin_plot(result, "Locally Linear Embedding")

# %% [markdown]
# ### TSNE

# %%
X = model2.wv[model2.wv.vocab]
tsne = TSNE(n_components=2)
result= tsne.fit_transform(X)

# %%
annotated_plot(result, "T-SNE")

# %%
mapping_by_category_plot(result, "T-SNE")

# %%
mapping_by_origin_plot(result, "T-SNE")

# %%
model = model2

# %%
vocab = set(model.wv.index2word)

def recipe_vector(recipe_array, model, num_dim, vocab):
    ingredients = list(set(recipe_array))
    recipe_vec = np.zeros((num_dim, ), dtype='float32')
    n_ingredients = 0
    for ingredient in ingredients:
        if ingredient in vocab:
            n_ingredients += 1
            recipe_vec = np.add(recipe_vec, model.wv[ingredient])
    if (n_ingredients > 0):
        recipe_vec = np.divide(recipe_vec, n_ingredients)
    return recipe_vec

# %%
#similarity score between first 2 recipes

r1_vec =  recipe_vector(list_of_ingredients[0], model, 20, vocab)
r2_vec = recipe_vector(list_of_ingredients[1], model, 20, vocab)

sim = 1 - spatial.distance.cosine(r1_vec, r2_vec)

print(sim)
# Out:
# 0.8277560472488403

# %%
#best recommendation for the 1st recipe

vec_list = list()
for i in range(len(list_of_ingredients)):
    vec = recipe_vector(list_of_ingredients[i], model, 20, vocab)
    vec_list.append(vec)
    
similarity_score = list()
for i in range(len(list_of_ingredients)):
    sim = 1 - spatial.distance.cosine(vec_list[0], vec_list[i])
    similarity_score.append(sim)

index = np.argsort(similarity_score)[-2]
print(list_of_ingredients[index], list_of_ingredients[0])
# Out:
# ['chicken breasts', 'chili', 'lemon', 'onion', 'cumin', 'chicken stock', 'tomato', 'garlic', 'olive oil'] ['chili', 'creme fraiche', 'onion', 'butternut squash', 'vegetable stock', 'garlic', 'olive oil', 'butter']

# %%
def recommended_recipe(ingredients_for_one_recipe, ingredients_for_all_recipes):

    vec_list = list()
    similarity_score = list()
    vec_recipe = recipe_vector(ingredients_for_one_recipe, model, 20, vocab)
    
    for i in range(len(ingredients_for_all_recipes)):
        vec = recipe_vector(ingredients_for_all_recipes[i], model, 20, vocab)
        vec_list.append(vec)
        sim = 1 - spatial.distance.cosine(vec_recipe, vec_list[i])
        similarity_score.append(sim)

    index = np.argsort(similarity_score)[-2]
    return list_of_ingredients[index], index

# %%
def recommended_recipe_second(ingredients_for_one_recipe, ingredients_for_all_recipes):

    vec_list = list()
    similarity_score = list() 
    vec_recipe = recipe_vector(ingredients_for_one_recipe, model, 20, vocab)

    for i in range(len(ingredients_for_all_recipes)):
        vec = recipe_vector(ingredients_for_all_recipes[i], model, 20, vocab)
        vec_list.append(vec)
        sim = 1 - spatial.distance.cosine(vec_recipe, vec_list[i])
        similarity_score.append(sim)

    index = np.argsort(similarity_score)[-3]
    return list_of_ingredients[index], index

# %%
def find_index_with_recipe_name(recipe_name):
    true_false = recipes_df_joined[["name"]] == recipe_name
    index = np.where(true_false)[0][0]
    return index

# %%
def recommender(recipe_name):
    index = find_index_with_recipe_name(recipe_name)
    ingredients_recipe = list_of_ingredients[index]
    ingredients_reco, index_new = recommended_recipe(ingredients_recipe, list_of_ingredients)
    ingredients_reco_second, index_new_second = recommended_recipe_second(ingredients_recipe, list_of_ingredients)
    recipe = recipes_df_joined.iloc[index,3]
    reco = recipes_df_joined.iloc[index_new,3]
    reco_second = recipes_df_joined.iloc[index_new_second,3]
    both_recos = ";".join([reco,reco_second])
    print("current recipe : ", recipe,". Ingredients : ", ingredients_recipe)
    print("                   ")
    print("recommended recipe 1:", reco,". Ingredients : ", ingredients_reco)
    print("                   ")
    print("recommended recipe 2:", reco_second, ". Ingredients : ", ingredients_reco_second)
    return both_recos

# %% [markdown]
# Good examples

# %%
print(recommender("Mushroom soup"));
# Out:
# current recipe :  Mushroom soup . Ingredients :  ['parsley', 'onion', 'bay leaf', 'garlic', 'chicken stock', 'flour', 'mushroom', 'butter', 'cream']
#
# recommended recipe 1: One-pot chicken chasseur . Ingredients :  ['thyme', 'onion', 'mushroom', 'red wine', 'chicken stock', 'chicken legs', 'garlic', 'olive oil', 'butter', 'tomato sauce']
#
# recommended recipe 2: Mushroom risotto . Ingredients :  ['parmesan', 'parsley', 'onion', 'white wine', 'risotto rice', 'garlic', 'vegetable stock', 'mushroom', 'butter', 'olive oil']
# One-pot chicken chasseur;Mushroom risotto

# %%
print(recommender("Best ever chunky guacamole"))
# Out:
# current recipe Best ever chunky guacamole ['avocado', 'lime', 'onion', 'coriander', 'tomato', 'chili']
#
# recommended recipe 1: Mexican bean soup with guacamole ['garlic', 'avocado', 'chili', 'lime', 'vegetable stock', 'onion', 'sunflower oil', 'pepper', 'coriander', 'tomato', 'cumin', 'beans']
#
# recommended recipe 2: Mexican penne with avocado ['garlic', 'corn', 'avocado', 'chili', 'lime', 'vegetable stock', 'onion', 'sunflower oil', 'pepper', 'coriander', 'tomato', 'cumin', 'penne']
# ['Mexican bean soup with guacamole', 'Mexican penne with avocado']

# %%
recommender("Mozzarella peppers with chunky Italian dressing");
# Out:
# current recipe Mozzarella peppers with chunky Italian dressing ['anchovy', 'mozzarella', 'pepper', 'basil', 'tomato', 'balsamic vinegar', 'olive']
#
# recommended recipe 1: Italian toasties ['ham', 'cheese', 'onion', 'mozzarella', 'oat bread', 'sundried tomato', 'olive', 'olive oil']
#
# recommended recipe 2: Italian-style stuffed aubergines ['garlic', 'cherry tomatoes', 'breadcrumb', 'eggplant', 'onion', 'mozzarella', 'basil', 'olive', 'olive oil']

# %% [markdown]
# Moroccan chickpea soup
# Pumpkin soup
# Best ever chunky guacamole
#
# Chicken biryani
# Chicken & chorizo jambalaya
# Italian cottage pie
#
#
# Cherry, almond & lemon mascarpone tart
# Somerset Pomona, apple & almond cake
# Tiramisu ice-cream cake
# Vanilla panna cotta

# %% [markdown]
# STARTER

# %%
recommender("Moroccan chickpea soup");
# Out:
# current recipe :  Moroccan chickpea soup . Ingredients :  ['chickpea', 'lemon', 'onion', 'celery', 'beans', 'tomato', 'vegetable stock', 'coriander', 'cumin', 'olive oil']
#
# recommended recipe 1: Mexican fiesta rice . Ingredients :  ['pepper', 'rice', 'onion', 'garlic', 'vegetable stock', 'coriander', 'cumin', 'olive oil', 'tomato sauce']
#
# recommended recipe 2: Red lentil, chickpea & chilli soup . Ingredients :  ['yogurt', 'chickpea', 'chili flakes', 'onion', 'tomato', 'vegetable stock', 'coriander', 'cumin', 'olive oil', 'lentils']

# %%
recommender("Pumpkin soup");
# Out:
# current recipe :  Pumpkin soup . Ingredients :  ['cream', 'vegetable stock', 'onion', 'pumpkin seeds', 'butternut squash', 'olive oil']
#
# recommended recipe 1: Butternut squash soup with chilli & crème fraîche . Ingredients :  ['garlic', 'vegetable stock', 'onion', 'creme fraiche', 'butternut squash', 'chili', 'butter', 'olive oil']
#
# recommended recipe 2: Italian chicken & butternut pie . Ingredients :  ['garlic', 'parmesan', 'flour', 'marjoram', 'chicken breasts', 'red wine', 'rowanberry', 'tomato sauce', 'pancetta', 'onion', 'butternut squash', 'olive oil']

# %%
recommender("Best ever chunky guacamole");
# Out:
# current recipe :  Best ever chunky guacamole . Ingredients :  ['avocado', 'lime', 'onion', 'coriander', 'tomato', 'chili']
#
# recommended recipe 1: Mexican bean soup with guacamole . Ingredients :  ['garlic', 'avocado', 'chili', 'lime', 'vegetable stock', 'onion', 'sunflower oil', 'pepper', 'coriander', 'tomato', 'cumin', 'beans']
#
# recommended recipe 2: Mexican penne with avocado . Ingredients :  ['garlic', 'corn', 'avocado', 'chili', 'lime', 'vegetable stock', 'onion', 'sunflower oil', 'pepper', 'coriander', 'tomato', 'cumin', 'penne']

# %%
recommender("Chicken biryani");
# Out:
# current recipe :  Chicken biryani . Ingredients :  ['raisins', 'chicken stock', 'chicken breasts', 'curry paste', 'bay leaf', 'ground turmeric', 'cinnamon stick', 'onion', 'coriander', 'cardamom', 'basmati rice', 'butter']
#
# recommended recipe 1: Home-style chicken curry . Ingredients :  ['garlic', 'chicken stock', 'caster sugar', 'tomato', 'chicken thighs', 'ginger', 'ground turmeric', 'sunflower oil', 'cinnamon stick', 'garam masala', 'fennel seeds', 'coriander', 'onion', 'chili flakes', 'cumin']
#
# recommended recipe 2: Chicken, sweet potato & coconut curry . Ingredients :  ['chicken stock', 'coconut milk', 'peas', 'chicken breasts', 'curry paste', 'sunflower oil', 'lentils', 'sweet potato']

# %%
recommender("Italian cottage pie");
# Out:
# current recipe :  Italian cottage pie . Ingredients :  ['oregano', 'parmesan', 'potatoes', 'pancetta', 'beef', 'butter']
#
# recommended recipe 1: Italian meatloaf . Ingredients :  ['garlic', 'beef mince', 'parmesan', 'tomato puree', 'breadcrumb', 'eggs', 'pancetta', 'onion']
#
# recommended recipe 2: Cottage pie . Ingredients :  ['garlic', 'beef mince', 'flour', 'celery', 'thyme', 'cheddar', 'potatoes', 'tomato sauce', 'nutmeg', 'bay leaf', 'onion', 'milk', 'carrots', 'beef stock', 'butter', 'olive oil']

# %%
recommender("Cherry, almond & lemon mascarpone tart");
# Out:
# current recipe :  Cherry, almond & lemon mascarpone tart . Ingredients :  ['mascarpone', 'caster sugar', 'eggs', 'lemon', 'sugar', 'cherries', 'butter', 'ground almond']
#
# recommended recipe 1: Raspberry bakewell cake . Ingredients :  ['vanilla', 'self-raising flour', 'caster sugar', 'eggs', 'raspberry', 'sugar', 'butter', 'ground almond']
#
# recommended recipe 2: New York cheesecake . Ingredients :  ['flour', 'vanilla', 'caster sugar', 'biscuits', 'eggs', 'soured cream', 'lemon', 'sugar', 'cream cheese', 'butter']

# %%
recommender("Somerset Pomona, apple & almond cake");
# Out:
# current recipe :  Somerset Pomona, apple & almond cake . Ingredients :  ['self-raising flour', 'caster sugar', 'Somerset Pomona', 'eggs', 'ground almond', 'butter', 'apple']
#
# recommended recipe 1: Raspberry bakewell cake . Ingredients :  ['vanilla', 'self-raising flour', 'caster sugar', 'eggs', 'raspberry', 'sugar', 'butter', 'ground almond']
#
# recommended recipe 2: Caramelised apple cake with streusel topping . Ingredients :  ['flour', 'vanilla', 'baking powder', 'ground cinnamon', 'eggs', 'demerara sugar', 'light brown sugar', 'butter', 'apple', 'hazelnut', 'milk']

# %%
recommender("Tiramisu ice-cream cake");
# Out:
# current recipe :  Tiramisu ice-cream cake . Ingredients :  ['cocoa', 'chocolate', 'mascarpone', 'caster sugar', 'cream', 'biscuits', 'coffee', 'dark chocolate', 'marsala wine', 'brandy']
#
# recommended recipe 1: Best ever tiramisu . Ingredients :  ['cocoa', 'mascarpone', 'caster sugar', 'cream', 'sponge finger', 'coffee', 'dark chocolate', 'marsala wine']
#
# recommended recipe 2: Next level tiramisu . Ingredients :  ['cocoa', 'vanilla', 'mascarpone', 'caster sugar', 'cream', 'biscuits', 'nutmeg', 'eggs', 'coffee', 'marsala wine', 'cocoa powder']

# %%
recommender("Vanilla panna cotta");
# Out:
# current recipe :  Vanilla panna cotta . Ingredients :  ['gelatin', 'vanilla', 'caster sugar', 'cream', 'strawberry', 'milk']
#
# recommended recipe 1: Strawberry cheesecake in 4 easy steps . Ingredients :  ['vanilla', 'cream', 'biscuits', 'strawberry', 'sugar', 'cream cheese', 'butter']
#
# recommended recipe 2: Strawberry parfait with Vin Santo, mascarpone & biscotti . Ingredients :  ['mascarpone', 'caster sugar', 'biscuits', 'strawberry', 'soured cream', 'white wine']

# %%
recipes_name = recipes_df_joined[["name"]]
for i in range(len(recipes_name)):
    recommender(recipes_name.iloc[i])
# Out:
# current recipe :  Butternut squash soup with chilli & crème fraîche . Ingredients :  ['garlic', 'vegetable stock', 'onion', 'creme fraiche', 'butternut squash', 'chili', 'butter', 'olive oil']
#
# recommended recipe 1: Mexican soup with chicken . Ingredients :  ['garlic', 'chicken stock', 'chili', 'chicken breasts', 'onion', 'lemon', 'tomato', 'cumin', 'olive oil']
#
# recommended recipe 2: Mexican fiesta rice . Ingredients :  ['garlic', 'vegetable stock', 'tomato sauce', 'rice', 'onion', 'pepper', 'coriander', 'cumin', 'olive oil']
# =========================================
# current recipe :  Moroccan chickpea soup . Ingredients :  ['celery', 'vegetable stock', 'onion', 'olive oil', 'coriander', 'lemon', 'tomato', 'cumin', 'beans', 'chickpea']
#
# recommended recipe 1: Mexican fiesta rice . Ingredients :  ['garlic', 'vegetable stock', 'tomato sauce', 'rice', 'onion', 'pepper', 'coriander', 'cumin', 'olive oil']
#
# recommended recipe 2: Red lentil, chickpea & chilli soup . Ingredients :  ['vegetable stock', 'tomato', 'onion', 'olive oil', 'lentils', 'coriander', 'chili flakes', 'yogurt', 'cumin', 'chickpea']
# =========================================
# current recipe :  Broccoli & stilton soup . Ingredients :  ['celery', 'broccoli', 'potatoes', 'vegetable stock', 'onion', 'sunflower oil', 'leek', 'butter', 'stilton']
#
# recommended recipe 1: Chunky cheddar & celeriac soup . Ingredients :  ['cheddar', 'potatoes', 'vegetable stock', 'onion', 'lemon', 'butter', 'sage', 'celeriac']
#
# recommended recipe 2: Crusty cheddar pies . Ingredients :  ['flour', 'cheddar', 'peas', 'broccoli', 'potatoes', 'mustard', 'leek', 'yogurt', 'butter', 'celeriac', 'milk']
# =========================================
# current recipe :  Mushroom risotto . Ingredients :  ['garlic', 'butter', 'parmesan', 'parsley', 'vegetable stock', 'onion', 'white wine', 'risotto rice', 'mushroom', 'olive oil']
#
# recommended recipe 1: Red wine risotto . Ingredients :  ['risotto rice', 'parmesan', 'red wine', 'onion', 'butter']
#
# recommended recipe 2: One-pot chicken chasseur . Ingredients :  ['garlic', 'chicken stock', 'thyme', 'chicken legs', 'red wine', 'tomato sauce', 'onion', 'butter', 'mushroom', 'olive oil']
# =========================================
# current recipe :  Spicy roasted parsnip soup . Ingredients :  ['garlic', 'parsnip', 'vegetable stock', 'ground turmeric', 'onion', 'coriander', 'lemon', 'tomato', 'cumin', 'mustard', 'olive oil']
#
# recommended recipe 1: Mexican soup with chicken . Ingredients :  ['garlic', 'chicken stock', 'chili', 'chicken breasts', 'onion', 'lemon', 'tomato', 'cumin', 'olive oil']
#
# recommended recipe 2: Red lentil, chickpea & chilli soup . Ingredients :  ['vegetable stock', 'tomato', 'onion', 'olive oil', 'lentils', 'coriander', 'chili flakes', 'yogurt', 'cumin', 'chickpea']
# =========================================
# current recipe :  Pumpkin soup . Ingredients :  ['cream', 'vegetable stock', 'onion', 'pumpkin seeds', 'butternut squash', 'olive oil']
#
# recommended recipe 1: Butternut squash soup with chilli & crème fraîche . Ingredients :  ['garlic', 'vegetable stock', 'onion', 'creme fraiche', 'butternut squash', 'chili', 'butter', 'olive oil']
#
# recommended recipe 2: Italian chicken & butternut pie . Ingredients :  ['garlic', 'parmesan', 'flour', 'marjoram', 'chicken breasts', 'red wine', 'rowanberry', 'tomato sauce', 'pancetta', 'onion', 'butternut squash', 'olive oil']
# =========================================
# current recipe :  Smoked salmon with prawns, horseradish cream & lime vinaigrette . Ingredients :  ['prawns', 'smoked salmon', 'lime', 'creme fraiche', 'salad', 'ginger', 'honey', 'olive oil']
#
# recommended recipe 1: Prawn cakes with cucumber peanut relish . Ingredients :  ['cucumber', 'shallot', 'rice vinegar', 'prawns', 'chili', 'caster sugar', 'lime', 'fish sauce', 'mint', 'peanuts', 'sunflower oil', 'chili flakes', 'coriander', 'sugar', 'salad', 'ginger']
#
# recommended recipe 2: Mexican lime chicken . Ingredients :  ['garlic', 'caster sugar', 'lime', 'chicken breasts', 'paprika', 'coriander', 'lemon', 'chili', 'olive oil']
# =========================================
# current recipe :  Smoked fish & potato latkes sharing platter . Ingredients :  ['garlic', 'flour', 'parsley', 'smoked salmon', 'potatoes', 'eggs', 'onion', 'creme fraiche', 'smoked mackerel', 'lemon', 'butter', 'olive oil']
#
# recommended recipe 1: Butternut squash soup with chilli & crème fraîche . Ingredients :  ['garlic', 'vegetable stock', 'onion', 'creme fraiche', 'butternut squash', 'chili', 'butter', 'olive oil']
#
# recommended recipe 2: Wild garlic butter on music paper bread . Ingredients :  ['garlic', 'flour', 'salt', 'semolina', 'olive oil']
# =========================================
# current recipe :  Chunky minestrone soup . Ingredients :  ['garlic', 'celery', 'carrots', 'potatoes', 'spaghetti', 'vegetable stock', 'tomato sauce', 'tomato', 'onion', 'cabbage', 'butter', 'olive oil']
#
# recommended recipe 1: Veggie shepherd's pie with sweet potato mash . Ingredients :  ['thyme', 'cheddar', 'sweet potato', 'red wine', 'vegetable stock', 'tomato', 'onion', 'lentils', 'carrots', 'butter', 'olive oil']
#
# recommended recipe 2: Cottage pie . Ingredients :  ['garlic', 'beef mince', 'flour', 'celery', 'thyme', 'cheddar', 'potatoes', 'tomato sauce', 'nutmeg', 'bay leaf', 'onion', 'milk', 'carrots', 'beef stock', 'butter', 'olive oil']
# =========================================
# current recipe :  Prawn cakes with cucumber peanut relish . Ingredients :  ['cucumber', 'shallot', 'rice vinegar', 'prawns', 'chili', 'caster sugar', 'lime', 'fish sauce', 'mint', 'peanuts', 'sunflower oil', 'chili flakes', 'coriander', 'sugar', 'salad', 'ginger']
#
# recommended recipe 1: Smoked salmon with prawns, horseradish cream & lime vinaigrette . Ingredients :  ['prawns', 'smoked salmon', 'lime', 'creme fraiche', 'salad', 'ginger', 'honey', 'olive oil']
#
# recommended recipe 2: Mexican lime chicken . Ingredients :  ['garlic', 'caster sugar', 'lime', 'chicken breasts', 'paprika', 'coriander', 'lemon', 'chili', 'olive oil']
# =========================================
# current recipe :  Best ever chunky guacamole . Ingredients :  ['avocado', 'lime', 'onion', 'coriander', 'tomato', 'chili']
#
# recommended recipe 1: Mexican bean soup with guacamole . Ingredients :  ['garlic', 'avocado', 'chili', 'lime', 'vegetable stock', 'onion', 'sunflower oil', 'pepper', 'coriander', 'tomato', 'cumin', 'beans']
#
# recommended recipe 2: Mexican penne with avocado . Ingredients :  ['garlic', 'corn', 'avocado', 'chili', 'lime', 'vegetable stock', 'onion', 'sunflower oil', 'pepper', 'coriander', 'tomato', 'cumin', 'penne']
# =========================================
# current recipe :  Mushroom soup . Ingredients :  ['garlic', 'chicken stock', 'flour', 'parsley', 'cream', 'bay leaf', 'onion', 'butter', 'mushroom']
#
# recommended recipe 1: One-pot chicken chasseur . Ingredients :  ['garlic', 'chicken stock', 'thyme', 'chicken legs', 'red wine', 'tomato sauce', 'onion', 'butter', 'mushroom', 'olive oil']
#
# recommended recipe 2: Mushroom risotto . Ingredients :  ['garlic', 'butter', 'parmesan', 'parsley', 'vegetable stock', 'onion', 'white wine', 'risotto rice', 'mushroom', 'olive oil']
# =========================================
# current recipe :  Chicken liver pâté . Ingredients :  ['garlic', 'thyme', 'brioche', 'chicken livers', 'butter', 'apple']
#
# recommended recipe 1: Apple & walnut marmalade . Ingredients :  ['walnut', 'bay leaf', 'light brown sugar', 'lemon', 'butter', 'apple']
#
# recommended recipe 2: Tomato tart with cheddar crust . Ingredients :  ['flour', 'thyme', 'cherry tomatoes', 'cheddar', 'eggs', 'soured cream', 'butter', 'mustard']
# =========================================
# current recipe :  Crayfish cocktail with horseradish cream . Ingredients :  ['avocado', 'lime', 'creme fraiche', 'pepper', 'crayfish tails', 'chicory']
#
# recommended recipe 1: Mexican chicken burger . Ingredients :  ['garlic', 'avocado', 'cherry tomatoes', 'lime', 'chicken breasts', 'brioche', 'cheese', 'pepper', 'chipotle paste']
#
# recommended recipe 2: Mexican penne with avocado . Ingredients :  ['garlic', 'corn', 'avocado', 'chili', 'lime', 'vegetable stock', 'onion', 'sunflower oil', 'pepper', 'coriander', 'tomato', 'cumin', 'penne']
# =========================================
# current recipe :  Lunchbox mains . Ingredients :  ['cheese', 'pasta']
#
# recommended recipe 1: No-knead grape & rosemary focaccia . Ingredients :  ['grape', 'cheese', 'salt', 'bread', 'rosemary', 'olive oil']
#
# recommended recipe 2: Italian stuffed chicken . Ingredients :  ['garlic', 'allherb and spice', 'cheese', 'tomato', 'olive', 'olive oil']
# =========================================
# current recipe :  Chicken & chorizo jambalaya . Ingredients :  ['garlic', 'chicken stock', 'chicken breasts', 'chorizo', 'rice', 'onion', 'pepper', 'tomato', 'cajun spices', 'olive oil']
#
# recommended recipe 1: Italian rice with chicken . Ingredients :  ['garlic', 'chicken stock', 'chicken breasts', 'rice', 'redskin onion', 'pepper', 'tomato', 'pesto', 'olive oil']
#
# recommended recipe 2: Mexican soup with chicken . Ingredients :  ['garlic', 'chicken stock', 'chili', 'chicken breasts', 'onion', 'lemon', 'tomato', 'cumin', 'olive oil']
# =========================================
# current recipe :  Spicy root & lentil casserole . Ingredients :  ['garlic', 'parsnip', 'potatoes', 'vegetable stock', 'curry paste', 'onion', 'sunflower oil', 'lentils', 'coriander', 'carrots']
#
# recommended recipe 1: Mexican sweet potato soup . Ingredients :  ['potatoes', 'vegetable stock', 'onion', 'sunflower oil', 'chipotle paste', 'coriander']
#
# recommended recipe 2: Spicy roasted parsnip soup . Ingredients :  ['garlic', 'parsnip', 'vegetable stock', 'ground turmeric', 'onion', 'coriander', 'lemon', 'tomato', 'cumin', 'mustard', 'olive oil']
# =========================================
# current recipe :  Red lentil, chickpea & chilli soup . Ingredients :  ['vegetable stock', 'tomato', 'onion', 'olive oil', 'lentils', 'coriander', 'chili flakes', 'yogurt', 'cumin', 'chickpea']
#
# recommended recipe 1: Moroccan chickpea soup . Ingredients :  ['celery', 'vegetable stock', 'onion', 'olive oil', 'coriander', 'lemon', 'tomato', 'cumin', 'beans', 'chickpea']
#
# recommended recipe 2: Spicy roasted parsnip soup . Ingredients :  ['garlic', 'parsnip', 'vegetable stock', 'ground turmeric', 'onion', 'coriander', 'lemon', 'tomato', 'cumin', 'mustard', 'olive oil']
# =========================================
# current recipe :  Summer-in-winter chicken . Ingredients :  ['cherry tomatoes', 'chicken breasts', 'creme fraiche', 'basil', 'pesto', 'olive oil']
#
# recommended recipe 1: Crisp Italian chicken & polenta . Ingredients :  ['garlic', 'parmesan', 'cherry tomatoes', 'chicken breasts', 'polenta', 'rosemary', 'olive oil']
#
# recommended recipe 2: Italian rice with chicken . Ingredients :  ['garlic', 'chicken stock', 'chicken breasts', 'rice', 'redskin onion', 'pepper', 'tomato', 'pesto', 'olive oil']
# =========================================
# current recipe :  Falafel burgers . Ingredients :  ['garlic', 'flour', 'parsley', 'tomato sauce', 'onion', 'sunflower oil', 'ground coriander', 'chili flakes', 'cumin', 'chickpea']
#
# recommended recipe 1: Red lentil, chickpea & chilli soup . Ingredients :  ['vegetable stock', 'tomato', 'onion', 'olive oil', 'lentils', 'coriander', 'chili flakes', 'yogurt', 'cumin', 'chickpea']
#
# recommended recipe 2: Mexican sweet potato soup . Ingredients :  ['potatoes', 'vegetable stock', 'onion', 'sunflower oil', 'chipotle paste', 'coriander']
# =========================================
# current recipe :  Mustard-stuffed chicken . Ingredients :  ['cheddar', 'chicken breasts', 'mozzarella', 'bacon', 'mustard']
#
# recommended recipe 1: Italian-style stuffed aubergines . Ingredients :  ['garlic', 'cherry tomatoes', 'breadcrumb', 'eggplant', 'onion', 'mozzarella', 'basil', 'olive', 'olive oil']
#
# recommended recipe 2: Italian toasties . Ingredients :  ['ham', 'cheese', 'onion', 'mozzarella', 'oat bread', 'sundried tomato', 'olive', 'olive oil']
# =========================================
# current recipe :  Chicken biryani . Ingredients :  ['raisins', 'chicken stock', 'chicken breasts', 'curry paste', 'bay leaf', 'ground turmeric', 'cinnamon stick', 'onion', 'coriander', 'cardamom', 'basmati rice', 'butter']
#
# recommended recipe 1: Home-style chicken curry . Ingredients :  ['garlic', 'chicken stock', 'caster sugar', 'tomato', 'chicken thighs', 'ginger', 'ground turmeric', 'sunflower oil', 'cinnamon stick', 'garam masala', 'fennel seeds', 'coriander', 'onion', 'chili flakes', 'cumin']
#
# recommended recipe 2: Chicken, sweet potato & coconut curry . Ingredients :  ['chicken stock', 'coconut milk', 'peas', 'chicken breasts', 'curry paste', 'sunflower oil', 'lentils', 'sweet potato']
# =========================================
# current recipe :  Creamy courgette lasagne . Ingredients :  ['garlic', 'cheddar', 'ricotta', 'lasagne sheets', 'onion', 'sunflower oil', 'courgette', 'tomato sauce']
#
# recommended recipe 1: Courgette, potato & cheddar soup . Ingredients :  ['potatoes', 'cheddar', 'vegetable stock', 'nutmeg', 'onion', 'courgette']
#
# recommended recipe 2: Cottage pie . Ingredients :  ['garlic', 'beef mince', 'flour', 'celery', 'thyme', 'cheddar', 'potatoes', 'tomato sauce', 'nutmeg', 'bay leaf', 'onion', 'milk', 'carrots', 'beef stock', 'butter', 'olive oil']
# =========================================
# current recipe :  Veggie shepherd's pie with sweet potato mash . Ingredients :  ['thyme', 'cheddar', 'sweet potato', 'red wine', 'vegetable stock', 'tomato', 'onion', 'lentils', 'carrots', 'butter', 'olive oil']
#
# recommended recipe 1: Chunky minestrone soup . Ingredients :  ['garlic', 'celery', 'carrots', 'potatoes', 'spaghetti', 'vegetable stock', 'tomato sauce', 'tomato', 'onion', 'cabbage', 'butter', 'olive oil']
#
# recommended recipe 2: One-pot chicken chasseur . Ingredients :  ['garlic', 'chicken stock', 'thyme', 'chicken legs', 'red wine', 'tomato sauce', 'onion', 'butter', 'mushroom', 'olive oil']
# =========================================
# current recipe :  Cottage pie . Ingredients :  ['garlic', 'beef mince', 'flour', 'celery', 'thyme', 'cheddar', 'potatoes', 'tomato sauce', 'nutmeg', 'bay leaf', 'onion', 'milk', 'carrots', 'beef stock', 'butter', 'olive oil']
#
# recommended recipe 1: Chunky minestrone soup . Ingredients :  ['garlic', 'celery', 'carrots', 'potatoes', 'spaghetti', 'vegetable stock', 'tomato sauce', 'tomato', 'onion', 'cabbage', 'butter', 'olive oil']
#
# recommended recipe 2: Veggie shepherd's pie with sweet potato mash . Ingredients :  ['thyme', 'cheddar', 'sweet potato', 'red wine', 'vegetable stock', 'tomato', 'onion', 'lentils', 'carrots', 'butter', 'olive oil']
# =========================================
# current recipe :  Home-style chicken curry . Ingredients :  ['garlic', 'chicken stock', 'caster sugar', 'tomato', 'chicken thighs', 'ginger', 'ground turmeric', 'sunflower oil', 'cinnamon stick', 'garam masala', 'fennel seeds', 'coriander', 'onion', 'chili flakes', 'cumin']
#
# recommended recipe 1: Mexican chicken stew . Ingredients :  ['garlic', 'caster sugar', 'chicken breasts', 'onion', 'sunflower oil', 'chipotle paste', 'coriander', 'tomato']
#
# recommended recipe 2: Red lentil, chickpea & chilli soup . Ingredients :  ['vegetable stock', 'tomato', 'onion', 'olive oil', 'lentils', 'coriander', 'chili flakes', 'yogurt', 'cumin', 'chickpea']
# =========================================
# current recipe :  The best spaghetti bolognese recipe . Ingredients :  ['red wine', 'chili', 'parmesan', 'spaghetti', 'bay leaf', 'bacon', 'beef stock', 'garlic', 'oregano', 'rosemary', 'tomato', 'carrots', 'olive oil', 'beef mince', 'celery', 'cherry tomatoes', 'onion', 'basil', 'tomato sauce']
#
# recommended recipe 1: Chunky minestrone soup . Ingredients :  ['garlic', 'celery', 'carrots', 'potatoes', 'spaghetti', 'vegetable stock', 'tomato sauce', 'tomato', 'onion', 'cabbage', 'butter', 'olive oil']
#
# recommended recipe 2: Italian-style beef stew . Ingredients :  ['garlic', 'onion', 'pepper', 'beef', 'rosemary', 'tomato', 'olive', 'olive oil']
# =========================================
# current recipe :  One-pot chicken chasseur . Ingredients :  ['garlic', 'chicken stock', 'thyme', 'chicken legs', 'red wine', 'tomato sauce', 'onion', 'butter', 'mushroom', 'olive oil']
#
# recommended recipe 1: Mushroom soup . Ingredients :  ['garlic', 'chicken stock', 'flour', 'parsley', 'cream', 'bay leaf', 'onion', 'butter', 'mushroom']
#
# recommended recipe 2: Mushroom risotto . Ingredients :  ['garlic', 'butter', 'parmesan', 'parsley', 'vegetable stock', 'onion', 'white wine', 'risotto rice', 'mushroom', 'olive oil']
# =========================================
# current recipe :  Chicken, sweet potato & coconut curry . Ingredients :  ['chicken stock', 'coconut milk', 'peas', 'chicken breasts', 'curry paste', 'sunflower oil', 'lentils', 'sweet potato']
#
# recommended recipe 1: Spicy root & lentil casserole . Ingredients :  ['garlic', 'parsnip', 'potatoes', 'vegetable stock', 'curry paste', 'onion', 'sunflower oil', 'lentils', 'coriander', 'carrots']
#
# recommended recipe 2: Chicken biryani . Ingredients :  ['raisins', 'chicken stock', 'chicken breasts', 'curry paste', 'bay leaf', 'ground turmeric', 'cinnamon stick', 'onion', 'coriander', 'cardamom', 'basmati rice', 'butter']
# =========================================
# current recipe :  Best ever chocolate brownies recipe . Ingredients :  ['flour', 'chocolate', 'caster sugar', 'eggs', 'dark chocolate', 'cocoa powder', 'butter']
#
# recommended recipe 1: Chocolate brownie cake . Ingredients :  ['butter', 'flour', 'chocolate', 'vanilla', 'caster sugar', 'golden syrup sugar', 'eggs', 'light brown sugar', 'cocoa powder', 'baking powder']
#
# recommended recipe 2: Gooseberry meringue tart . Ingredients :  ['gooseberry', 'flour', 'caster sugar', 'eggs', 'light brown sugar', 'puff pastry', 'butter']
# =========================================
# current recipe :  Brilliant banana loaf . Ingredients :  ['self-raising flour', 'caster sugar', 'baking powder', 'banana', 'eggs', 'sugar', 'butter']
#
# recommended recipe 1: Easy chocolate fudge cake . Ingredients :  ['butter', 'self-raising flour', 'caster sugar', 'golden syrup sugar', 'eggs', 'sunflower oil', 'sugar', 'cocoa powder', 'baking powder', 'milk']
#
# recommended recipe 2: Raspberry bakewell cake . Ingredients :  ['vanilla', 'self-raising flour', 'caster sugar', 'eggs', 'raspberry', 'sugar', 'butter', 'ground almond']
# =========================================
# current recipe :  Raspberry bakewell cake . Ingredients :  ['vanilla', 'self-raising flour', 'caster sugar', 'eggs', 'raspberry', 'sugar', 'butter', 'ground almond']
#
# recommended recipe 1: Brilliant banana loaf . Ingredients :  ['self-raising flour', 'caster sugar', 'baking powder', 'banana', 'eggs', 'sugar', 'butter']
#
# recommended recipe 2: Cherry, almond & lemon mascarpone tart . Ingredients :  ['mascarpone', 'caster sugar', 'eggs', 'lemon', 'sugar', 'cherries', 'butter', 'ground almond']
# =========================================
# current recipe :  Somerset Pomona, apple & almond cake . Ingredients :  ['self-raising flour', 'caster sugar', 'Somerset Pomona', 'eggs', 'ground almond', 'butter', 'apple']
#
# recommended recipe 1: Raspberry bakewell cake . Ingredients :  ['vanilla', 'self-raising flour', 'caster sugar', 'eggs', 'raspberry', 'sugar', 'butter', 'ground almond']
#
# recommended recipe 2: Caramelised apple cake with streusel topping . Ingredients :  ['flour', 'vanilla', 'baking powder', 'ground cinnamon', 'eggs', 'demerara sugar', 'light brown sugar', 'butter', 'apple', 'hazelnut', 'milk']
# =========================================
# current recipe :  Cherry, almond & lemon mascarpone tart . Ingredients :  ['mascarpone', 'caster sugar', 'eggs', 'lemon', 'sugar', 'cherries', 'butter', 'ground almond']
#
# recommended recipe 1: Raspberry bakewell cake . Ingredients :  ['vanilla', 'self-raising flour', 'caster sugar', 'eggs', 'raspberry', 'sugar', 'butter', 'ground almond']
#
# recommended recipe 2: New York cheesecake . Ingredients :  ['flour', 'vanilla', 'caster sugar', 'biscuits', 'eggs', 'soured cream', 'lemon', 'sugar', 'cream cheese', 'butter']
# =========================================
# current recipe :  Apple & walnut marmalade . Ingredients :  ['walnut', 'bay leaf', 'light brown sugar', 'lemon', 'butter', 'apple']
#
# recommended recipe 1: Caramelised apple cake with streusel topping . Ingredients :  ['flour', 'vanilla', 'baking powder', 'ground cinnamon', 'eggs', 'demerara sugar', 'light brown sugar', 'butter', 'apple', 'hazelnut', 'milk']
#
# recommended recipe 2: Gooseberry meringue tart . Ingredients :  ['gooseberry', 'flour', 'caster sugar', 'eggs', 'light brown sugar', 'puff pastry', 'butter']
# =========================================
# current recipe :  Chocolate brownie cake . Ingredients :  ['butter', 'flour', 'chocolate', 'vanilla', 'caster sugar', 'golden syrup sugar', 'eggs', 'light brown sugar', 'cocoa powder', 'baking powder']
#
# recommended recipe 1: Best ever chocolate brownies recipe . Ingredients :  ['flour', 'chocolate', 'caster sugar', 'eggs', 'dark chocolate', 'cocoa powder', 'butter']
#
# recommended recipe 2: Gooseberry meringue tart . Ingredients :  ['gooseberry', 'flour', 'caster sugar', 'eggs', 'light brown sugar', 'puff pastry', 'butter']
# =========================================
# current recipe :  Easy chocolate fudge cake . Ingredients :  ['butter', 'self-raising flour', 'caster sugar', 'golden syrup sugar', 'eggs', 'sunflower oil', 'sugar', 'cocoa powder', 'baking powder', 'milk']
#
# recommended recipe 1: Brilliant banana loaf . Ingredients :  ['self-raising flour', 'caster sugar', 'baking powder', 'banana', 'eggs', 'sugar', 'butter']
#
# recommended recipe 2: Chocolate brownie cake . Ingredients :  ['butter', 'flour', 'chocolate', 'vanilla', 'caster sugar', 'golden syrup sugar', 'eggs', 'light brown sugar', 'cocoa powder', 'baking powder']
# =========================================
# current recipe :  New York cheesecake . Ingredients :  ['flour', 'vanilla', 'caster sugar', 'biscuits', 'eggs', 'soured cream', 'lemon', 'sugar', 'cream cheese', 'butter']
#
# recommended recipe 1: Strawberry cheesecake in 4 easy steps . Ingredients :  ['vanilla', 'cream', 'biscuits', 'strawberry', 'sugar', 'cream cheese', 'butter']
#
# recommended recipe 2: Cherry, almond & lemon mascarpone tart . Ingredients :  ['mascarpone', 'caster sugar', 'eggs', 'lemon', 'sugar', 'cherries', 'butter', 'ground almond']
# =========================================
# current recipe :  Medley of summer fruits . Ingredients :  ['vanilla', 'caster sugar', 'red wine', 'strawberry', 'melon', 'mint', 'raspberry', 'basil', 'white wine']
#
# recommended recipe 1: Strawberry & mint granita . Ingredients :  ['strawberry', 'mint', 'caster sugar']
#
# recommended recipe 2: Vanilla panna cotta . Ingredients :  ['gelatin', 'vanilla', 'caster sugar', 'cream', 'strawberry', 'milk']
# =========================================
# current recipe :  Caramelised apple cake with streusel topping . Ingredients :  ['flour', 'vanilla', 'baking powder', 'ground cinnamon', 'eggs', 'demerara sugar', 'light brown sugar', 'butter', 'apple', 'hazelnut', 'milk']
#
# recommended recipe 1: Plum crumble . Ingredients :  ['flour', 'caster sugar', 'orange', 'demerara sugar', 'light brown sugar', 'plum', 'butter', 'ground almond', 'ground cinnamon']
#
# recommended recipe 2: Cheddar & hazelnut shortbread . Ingredients :  ['flour', 'cheddar', 'eggs', 'butter', 'hazelnut']
# =========================================
# current recipe :  Gooseberry meringue tart . Ingredients :  ['gooseberry', 'flour', 'caster sugar', 'eggs', 'light brown sugar', 'puff pastry', 'butter']
#
# recommended recipe 1: Chocolate brownie cake . Ingredients :  ['butter', 'flour', 'chocolate', 'vanilla', 'caster sugar', 'golden syrup sugar', 'eggs', 'light brown sugar', 'cocoa powder', 'baking powder']
#
# recommended recipe 2: Caramelised apple cake with streusel topping . Ingredients :  ['flour', 'vanilla', 'baking powder', 'ground cinnamon', 'eggs', 'demerara sugar', 'light brown sugar', 'butter', 'apple', 'hazelnut', 'milk']
# =========================================
# current recipe :  Strawberry cheesecake in 4 easy steps . Ingredients :  ['vanilla', 'cream', 'biscuits', 'strawberry', 'sugar', 'cream cheese', 'butter']
#
# recommended recipe 1: New York cheesecake . Ingredients :  ['flour', 'vanilla', 'caster sugar', 'biscuits', 'eggs', 'soured cream', 'lemon', 'sugar', 'cream cheese', 'butter']
#
# recommended recipe 2: Vanilla panna cotta . Ingredients :  ['gelatin', 'vanilla', 'caster sugar', 'cream', 'strawberry', 'milk']
# =========================================
# current recipe :  Plum crumble . Ingredients :  ['flour', 'caster sugar', 'orange', 'demerara sugar', 'light brown sugar', 'plum', 'butter', 'ground almond', 'ground cinnamon']
#
# recommended recipe 1: Caramelised apple cake with streusel topping . Ingredients :  ['flour', 'vanilla', 'baking powder', 'ground cinnamon', 'eggs', 'demerara sugar', 'light brown sugar', 'butter', 'apple', 'hazelnut', 'milk']
#
# recommended recipe 2: Orange polenta cake . Ingredients :  ['flour', 'caster sugar', 'baking powder', 'orange', 'eggs', 'polenta', 'butter']
# =========================================
# current recipe :  Strawberry parfait with Vin Santo, mascarpone & biscotti . Ingredients :  ['mascarpone', 'caster sugar', 'biscuits', 'strawberry', 'soured cream', 'white wine']
#
# recommended recipe 1: Strawberry cheesecake in 4 easy steps . Ingredients :  ['vanilla', 'cream', 'biscuits', 'strawberry', 'sugar', 'cream cheese', 'butter']
#
# recommended recipe 2: Vanilla panna cotta . Ingredients :  ['gelatin', 'vanilla', 'caster sugar', 'cream', 'strawberry', 'milk']
# =========================================
# current recipe :  Cheddar scones . Ingredients :  ['flour', 'butter', 'cheddar', 'milk']
#
# recommended recipe 1: Cheddar & hazelnut shortbread . Ingredients :  ['flour', 'cheddar', 'eggs', 'butter', 'hazelnut']
#
# recommended recipe 2: Double-baked cheddar soufflés . Ingredients :  ['flour', 'cheddar', 'cream', 'nutmeg', 'eggs', 'bay leaf', 'onion', 'butter', 'mustard', 'milk']
# =========================================
# current recipe :  Courgette, potato & cheddar soup . Ingredients :  ['potatoes', 'cheddar', 'vegetable stock', 'nutmeg', 'onion', 'courgette']
#
# recommended recipe 1: Chunky cheddar & celeriac soup . Ingredients :  ['cheddar', 'potatoes', 'vegetable stock', 'onion', 'lemon', 'butter', 'sage', 'celeriac']
#
# recommended recipe 2: Creamy courgette lasagne . Ingredients :  ['garlic', 'cheddar', 'ricotta', 'lasagne sheets', 'onion', 'sunflower oil', 'courgette', 'tomato sauce']
# =========================================
# current recipe :  Sticky onion & cheddar quiche . Ingredients :  ['flour', 'cheddar', 'cream', 'eggs', 'onion', 'butter']
#
# recommended recipe 1: Double-baked cheddar soufflés . Ingredients :  ['flour', 'cheddar', 'cream', 'nutmeg', 'eggs', 'bay leaf', 'onion', 'butter', 'mustard', 'milk']
#
# recommended recipe 2: Cheddar & hazelnut shortbread . Ingredients :  ['flour', 'cheddar', 'eggs', 'butter', 'hazelnut']
# =========================================
# current recipe :  Cheddar & sweetcorn scones . Ingredients :  ['corn', 'flour', 'thyme', 'cheddar', 'baking powder', 'paprika', 'lemon', 'butter', 'mustard', 'milk']
#
# recommended recipe 1: Cheddar & sage scones . Ingredients :  ['flour', 'cheddar', 'mustard', 'eggs', 'buttermilk', 'butter', 'sage']
#
# recommended recipe 2: Potted cheddar with ale & mustard . Ingredients :  ['mustard', 'thyme', 'butter', 'cheddar']
# =========================================
# current recipe :  Chunky cheddar & celeriac soup . Ingredients :  ['cheddar', 'potatoes', 'vegetable stock', 'onion', 'lemon', 'butter', 'sage', 'celeriac']
#
# recommended recipe 1: Courgette, potato & cheddar soup . Ingredients :  ['potatoes', 'cheddar', 'vegetable stock', 'nutmeg', 'onion', 'courgette']
#
# recommended recipe 2: Broccoli & stilton soup . Ingredients :  ['celery', 'broccoli', 'potatoes', 'vegetable stock', 'onion', 'sunflower oil', 'leek', 'butter', 'stilton']
# =========================================
# current recipe :  Cheddar & sage scones . Ingredients :  ['flour', 'cheddar', 'mustard', 'eggs', 'buttermilk', 'butter', 'sage']
#
# recommended recipe 1: Cheddar & sweetcorn scones . Ingredients :  ['corn', 'flour', 'thyme', 'cheddar', 'baking powder', 'paprika', 'lemon', 'butter', 'mustard', 'milk']
#
# recommended recipe 2: Courgette & cheddar soda bread . Ingredients :  ['flour', 'thyme', 'cheddar', 'eggs', 'honey', 'buttermilk', 'courgette', 'baking powder']
# =========================================
# current recipe :  Crusty cheddar pies . Ingredients :  ['flour', 'cheddar', 'peas', 'broccoli', 'potatoes', 'mustard', 'leek', 'yogurt', 'butter', 'celeriac', 'milk']
#
# recommended recipe 1: Broccoli & stilton soup . Ingredients :  ['celery', 'broccoli', 'potatoes', 'vegetable stock', 'onion', 'sunflower oil', 'leek', 'butter', 'stilton']
#
# recommended recipe 2: Chunky cheddar & celeriac soup . Ingredients :  ['cheddar', 'potatoes', 'vegetable stock', 'onion', 'lemon', 'butter', 'sage', 'celeriac']
# =========================================
# current recipe :  Courgette & cheddar soda bread . Ingredients :  ['flour', 'thyme', 'cheddar', 'eggs', 'honey', 'buttermilk', 'courgette', 'baking powder']
#
# recommended recipe 1: Cheddar & sage scones . Ingredients :  ['flour', 'cheddar', 'mustard', 'eggs', 'buttermilk', 'butter', 'sage']
#
# recommended recipe 2: Jalapeño & cheddar corn rolls . Ingredients :  ['corn', 'flour', 'cheddar', 'caster sugar', 'eggs', 'buttermilk', 'chili', 'baking powder']
# =========================================
# current recipe :  Double-baked cheddar soufflés . Ingredients :  ['flour', 'cheddar', 'cream', 'nutmeg', 'eggs', 'bay leaf', 'onion', 'butter', 'mustard', 'milk']
#
# recommended recipe 1: Sticky onion & cheddar quiche . Ingredients :  ['flour', 'cheddar', 'cream', 'eggs', 'onion', 'butter']
#
# recommended recipe 2: Cheddar & hazelnut shortbread . Ingredients :  ['flour', 'cheddar', 'eggs', 'butter', 'hazelnut']
# =========================================
# current recipe :  Jalapeño & cheddar corn rolls . Ingredients :  ['corn', 'flour', 'cheddar', 'caster sugar', 'eggs', 'buttermilk', 'chili', 'baking powder']
#
# recommended recipe 1: Courgette & cheddar soda bread . Ingredients :  ['flour', 'thyme', 'cheddar', 'eggs', 'honey', 'buttermilk', 'courgette', 'baking powder']
#
# recommended recipe 2: Cheddar & sweetcorn scones . Ingredients :  ['corn', 'flour', 'thyme', 'cheddar', 'baking powder', 'paprika', 'lemon', 'butter', 'mustard', 'milk']
# =========================================
# current recipe :  Courgette, potato & cheddar bread . Ingredients :  ['yeast', 'thyme', 'flour', 'cheddar', 'potatoes', 'courgette', 'olive oil']
#
# recommended recipe 1: Italian veggie cottage pie . Ingredients :  ['garlic', 'oregano', 'flour', 'cheddar', 'potatoes', 'eggplant', 'olive oil', 'spinach', 'sundried tomato', 'milk']
#
# recommended recipe 2: Courgette & cheddar soda bread . Ingredients :  ['flour', 'thyme', 'cheddar', 'eggs', 'honey', 'buttermilk', 'courgette', 'baking powder']
# =========================================
# current recipe :  Potted cheddar with ale & mustard . Ingredients :  ['mustard', 'thyme', 'butter', 'cheddar']
#
# recommended recipe 1: Cheddar & sweetcorn scones . Ingredients :  ['corn', 'flour', 'thyme', 'cheddar', 'baking powder', 'paprika', 'lemon', 'butter', 'mustard', 'milk']
#
# recommended recipe 2: Cheddar & sage scones . Ingredients :  ['flour', 'cheddar', 'mustard', 'eggs', 'buttermilk', 'butter', 'sage']
# =========================================
# current recipe :  Cheddar & hazelnut shortbread . Ingredients :  ['flour', 'cheddar', 'eggs', 'butter', 'hazelnut']
#
# recommended recipe 1: Sticky onion & cheddar quiche . Ingredients :  ['flour', 'cheddar', 'cream', 'eggs', 'onion', 'butter']
#
# recommended recipe 2: Caramelised apple cake with streusel topping . Ingredients :  ['flour', 'vanilla', 'baking powder', 'ground cinnamon', 'eggs', 'demerara sugar', 'light brown sugar', 'butter', 'apple', 'hazelnut', 'milk']
# =========================================
# current recipe :  Tomato tart with cheddar crust . Ingredients :  ['flour', 'thyme', 'cherry tomatoes', 'cheddar', 'eggs', 'soured cream', 'butter', 'mustard']
#
# recommended recipe 1: Double-baked cheddar soufflés . Ingredients :  ['flour', 'cheddar', 'cream', 'nutmeg', 'eggs', 'bay leaf', 'onion', 'butter', 'mustard', 'milk']
#
# recommended recipe 2: Cheddar & sage scones . Ingredients :  ['flour', 'cheddar', 'mustard', 'eggs', 'buttermilk', 'butter', 'sage']
# =========================================
# current recipe :  Membrillo, chorizo & cheddar toastie . Ingredients :  ['sage', 'cheddar', 'mayonnaise', 'chorizo', 'olive oil']
#
# recommended recipe 1: Chunky cheddar & celeriac soup . Ingredients :  ['cheddar', 'potatoes', 'vegetable stock', 'onion', 'lemon', 'butter', 'sage', 'celeriac']
#
# recommended recipe 2: Garlic & basil ciabatta . Ingredients :  ['garlic', 'parmesan', 'bread', 'mayonnaise', 'basil', 'butter']
# =========================================
# current recipe :  Mexican potatoes . Ingredients :  ['garlic', 'chili', 'potatoes', 'paprika', 'onion', 'soured cream', 'pepper', 'cumin', 'olive oil']
#
# recommended recipe 1: Mexican soup with chicken . Ingredients :  ['garlic', 'chicken stock', 'chili', 'chicken breasts', 'onion', 'lemon', 'tomato', 'cumin', 'olive oil']
#
# recommended recipe 2: Mexican fiesta rice . Ingredients :  ['garlic', 'vegetable stock', 'tomato sauce', 'rice', 'onion', 'pepper', 'coriander', 'cumin', 'olive oil']
# =========================================
# current recipe :  Mexican bake . Ingredients :  ['paprika', 'beans', 'cheddar', 'tomato sauce']
#
# recommended recipe 1: Mexican potatoes . Ingredients :  ['garlic', 'chili', 'potatoes', 'paprika', 'onion', 'soured cream', 'pepper', 'cumin', 'olive oil']
#
# recommended recipe 2: Mexican penne with avocado . Ingredients :  ['garlic', 'corn', 'avocado', 'chili', 'lime', 'vegetable stock', 'onion', 'sunflower oil', 'pepper', 'coriander', 'tomato', 'cumin', 'penne']
# =========================================
# current recipe :  Mexican chicken stew . Ingredients :  ['garlic', 'caster sugar', 'chicken breasts', 'onion', 'sunflower oil', 'chipotle paste', 'coriander', 'tomato']
#
# recommended recipe 1: Mexican soup with chicken . Ingredients :  ['garlic', 'chicken stock', 'chili', 'chicken breasts', 'onion', 'lemon', 'tomato', 'cumin', 'olive oil']
#
# recommended recipe 2: Mexican fiesta rice . Ingredients :  ['garlic', 'vegetable stock', 'tomato sauce', 'rice', 'onion', 'pepper', 'coriander', 'cumin', 'olive oil']
# =========================================
# current recipe :  Mexican penne with avocado . Ingredients :  ['garlic', 'corn', 'avocado', 'chili', 'lime', 'vegetable stock', 'onion', 'sunflower oil', 'pepper', 'coriander', 'tomato', 'cumin', 'penne']
#
# recommended recipe 1: Mexican bean soup with guacamole . Ingredients :  ['garlic', 'avocado', 'chili', 'lime', 'vegetable stock', 'onion', 'sunflower oil', 'pepper', 'coriander', 'tomato', 'cumin', 'beans']
#
# recommended recipe 2: Best ever chunky guacamole . Ingredients :  ['avocado', 'lime', 'onion', 'coriander', 'tomato', 'chili']
# =========================================
# current recipe :  Mexican beef chilli . Ingredients :  ['garlic', 'oregano', 'flour', 'cinnamon', 'ginger', 'onion', 'sunflower oil', 'chipotle paste', 'beef', 'cumin', 'beef stock', 'beans', 'tomato sauce']
#
# recommended recipe 1: Falafel burgers . Ingredients :  ['garlic', 'flour', 'parsley', 'tomato sauce', 'onion', 'sunflower oil', 'ground coriander', 'chili flakes', 'cumin', 'chickpea']
#
# recommended recipe 2: Mexican sweet potato soup . Ingredients :  ['potatoes', 'vegetable stock', 'onion', 'sunflower oil', 'chipotle paste', 'coriander']
# =========================================
# current recipe :  Mexican bean soup with guacamole . Ingredients :  ['garlic', 'avocado', 'chili', 'lime', 'vegetable stock', 'onion', 'sunflower oil', 'pepper', 'coriander', 'tomato', 'cumin', 'beans']
#
# recommended recipe 1: Mexican penne with avocado . Ingredients :  ['garlic', 'corn', 'avocado', 'chili', 'lime', 'vegetable stock', 'onion', 'sunflower oil', 'pepper', 'coriander', 'tomato', 'cumin', 'penne']
#
# recommended recipe 2: Best ever chunky guacamole . Ingredients :  ['avocado', 'lime', 'onion', 'coriander', 'tomato', 'chili']
# =========================================
# current recipe :  Mexican lime chicken . Ingredients :  ['garlic', 'caster sugar', 'lime', 'chicken breasts', 'paprika', 'coriander', 'lemon', 'chili', 'olive oil']
#
# recommended recipe 1: Best ever chunky guacamole . Ingredients :  ['avocado', 'lime', 'onion', 'coriander', 'tomato', 'chili']
#
# recommended recipe 2: Mexican potatoes . Ingredients :  ['garlic', 'chili', 'potatoes', 'paprika', 'onion', 'soured cream', 'pepper', 'cumin', 'olive oil']
# =========================================
# current recipe :  Mexican chicken stew with quinoa & beans . Ingredients :  ['chicken stock', 'chicken breasts', 'tomato sauce', 'quinoa', 'onion', 'pepper', 'chipotle paste', 'coriander', 'lemon', 'sugar', 'beans', 'olive oil']
#
# recommended recipe 1: Mexican chilli chicken . Ingredients :  ['chicken stock', 'avocado', 'chorizo', 'chicken thighs', 'onion', 'soured cream', 'pepper', 'coriander', 'lemon', 'tomato', 'cumin', 'beans', 'olive oil']
#
# recommended recipe 2: Mexican soup with chicken . Ingredients :  ['garlic', 'chicken stock', 'chili', 'chicken breasts', 'onion', 'lemon', 'tomato', 'cumin', 'olive oil']
# =========================================
# current recipe :  Mexican chicken burger . Ingredients :  ['garlic', 'avocado', 'cherry tomatoes', 'lime', 'chicken breasts', 'brioche', 'cheese', 'pepper', 'chipotle paste']
#
# recommended recipe 1: Crayfish cocktail with horseradish cream . Ingredients :  ['avocado', 'lime', 'creme fraiche', 'pepper', 'crayfish tails', 'chicory']
#
# recommended recipe 2: Mexican bean salad . Ingredients :  ['avocado', 'chili', 'cherry tomatoes', 'eggs', 'onion', 'coriander', 'cumin', 'beans']
# =========================================
# current recipe :  Mexican chilli chicken . Ingredients :  ['chicken stock', 'avocado', 'chorizo', 'chicken thighs', 'onion', 'soured cream', 'pepper', 'coriander', 'lemon', 'tomato', 'cumin', 'beans', 'olive oil']
#
# recommended recipe 1: Mexican chicken stew with quinoa & beans . Ingredients :  ['chicken stock', 'chicken breasts', 'tomato sauce', 'quinoa', 'onion', 'pepper', 'chipotle paste', 'coriander', 'lemon', 'sugar', 'beans', 'olive oil']
#
# recommended recipe 2: Mexican bean soup with guacamole . Ingredients :  ['garlic', 'avocado', 'chili', 'lime', 'vegetable stock', 'onion', 'sunflower oil', 'pepper', 'coriander', 'tomato', 'cumin', 'beans']
# =========================================
# current recipe :  Mexican bean salad . Ingredients :  ['avocado', 'chili', 'cherry tomatoes', 'eggs', 'onion', 'coriander', 'cumin', 'beans']
#
# recommended recipe 1: Mexican bean soup with guacamole . Ingredients :  ['garlic', 'avocado', 'chili', 'lime', 'vegetable stock', 'onion', 'sunflower oil', 'pepper', 'coriander', 'tomato', 'cumin', 'beans']
#
# recommended recipe 2: Best ever chunky guacamole . Ingredients :  ['avocado', 'lime', 'onion', 'coriander', 'tomato', 'chili']
# =========================================
# current recipe :  Mexican soup with chicken . Ingredients :  ['garlic', 'chicken stock', 'chili', 'chicken breasts', 'onion', 'lemon', 'tomato', 'cumin', 'olive oil']
#
# recommended recipe 1: Mexican fiesta rice . Ingredients :  ['garlic', 'vegetable stock', 'tomato sauce', 'rice', 'onion', 'pepper', 'coriander', 'cumin', 'olive oil']
#
# recommended recipe 2: Spicy roasted parsnip soup . Ingredients :  ['garlic', 'parsnip', 'vegetable stock', 'ground turmeric', 'onion', 'coriander', 'lemon', 'tomato', 'cumin', 'mustard', 'olive oil']
# =========================================
# current recipe :  Mexican sweet potato soup . Ingredients :  ['potatoes', 'vegetable stock', 'onion', 'sunflower oil', 'chipotle paste', 'coriander']
#
# recommended recipe 1: Moroccan chickpea soup . Ingredients :  ['celery', 'vegetable stock', 'onion', 'olive oil', 'coriander', 'lemon', 'tomato', 'cumin', 'beans', 'chickpea']
#
# recommended recipe 2: Spicy root & lentil casserole . Ingredients :  ['garlic', 'parsnip', 'potatoes', 'vegetable stock', 'curry paste', 'onion', 'sunflower oil', 'lentils', 'coriander', 'carrots']
# =========================================
# current recipe :  Mexican fiesta rice . Ingredients :  ['garlic', 'vegetable stock', 'tomato sauce', 'rice', 'onion', 'pepper', 'coriander', 'cumin', 'olive oil']
#
# recommended recipe 1: Mexican soup with chicken . Ingredients :  ['garlic', 'chicken stock', 'chili', 'chicken breasts', 'onion', 'lemon', 'tomato', 'cumin', 'olive oil']
#
# recommended recipe 2: Moroccan chickpea soup . Ingredients :  ['celery', 'vegetable stock', 'onion', 'olive oil', 'coriander', 'lemon', 'tomato', 'cumin', 'beans', 'chickpea']
# =========================================
# current recipe :  Mozzarella peppers with chunky Italian dressing . Ingredients :  ['anchovy', 'mozzarella', 'pepper', 'basil', 'tomato', 'balsamic vinegar', 'olive']
#
# recommended recipe 1: Italian toasties . Ingredients :  ['ham', 'cheese', 'onion', 'mozzarella', 'oat bread', 'sundried tomato', 'olive', 'olive oil']
#
# recommended recipe 2: Italian-style stuffed aubergines . Ingredients :  ['garlic', 'cherry tomatoes', 'breadcrumb', 'eggplant', 'onion', 'mozzarella', 'basil', 'olive', 'olive oil']
# =========================================
# current recipe :  Crab & citrus salad with Chardonnay dressing . Ingredients :  ['grapefruit', 'bitter orange', 'chive', 'vinegar', 'mayonnaise', 'oat bread', 'crab', 'sugar', 'salad', 'mustard', 'olive oil']
#
# recommended recipe 1: Radish confetti with salsa verde . Ingredients :  ['anchovy', 'parsley', 'capers', 'mint', 'vinegar', 'radish', 'mustard', 'olive oil']
#
# recommended recipe 2: Membrillo, chorizo & cheddar toastie . Ingredients :  ['sage', 'cheddar', 'mayonnaise', 'chorizo', 'olive oil']
# =========================================
# current recipe :  Tomato bruschetta . Ingredients :  ['garlic', 'bread', 'redskin onion', 'basil', 'tomato', 'balsamic vinegar', 'olive oil']
#
# recommended recipe 1: Acquacotta . Ingredients :  ['garlic', 'chicken stock', 'parsley', 'celery', 'thyme', 'bread', 'eggs', 'redskin onion', 'tomato', 'carrots', 'mushroom', 'olive oil']
#
# recommended recipe 2: Garlic & basil ciabatta . Ingredients :  ['garlic', 'parmesan', 'bread', 'mayonnaise', 'basil', 'butter']
# =========================================
# current recipe :  No-knead grape & rosemary focaccia . Ingredients :  ['grape', 'cheese', 'salt', 'bread', 'rosemary', 'olive oil']
#
# recommended recipe 1: Lunchbox mains . Ingredients :  ['cheese', 'pasta']
#
# recommended recipe 2: Crisp Italian chicken & polenta . Ingredients :  ['garlic', 'parmesan', 'cherry tomatoes', 'chicken breasts', 'polenta', 'rosemary', 'olive oil']
# =========================================
# current recipe :  Garlic & basil ciabatta . Ingredients :  ['garlic', 'parmesan', 'bread', 'mayonnaise', 'basil', 'butter']
#
# recommended recipe 1: Wild garlic butter on music paper bread . Ingredients :  ['garlic', 'flour', 'salt', 'semolina', 'olive oil']
#
# recommended recipe 2: Tomato bruschetta . Ingredients :  ['garlic', 'bread', 'redskin onion', 'basil', 'tomato', 'balsamic vinegar', 'olive oil']
# =========================================
# current recipe :  Wild garlic butter on music paper bread . Ingredients :  ['garlic', 'flour', 'salt', 'semolina', 'olive oil']
#
# recommended recipe 1: Garlic & basil ciabatta . Ingredients :  ['garlic', 'parmesan', 'bread', 'mayonnaise', 'basil', 'butter']
#
# recommended recipe 2: Tomato bruschetta . Ingredients :  ['garlic', 'bread', 'redskin onion', 'basil', 'tomato', 'balsamic vinegar', 'olive oil']
# =========================================
# current recipe :  Grilled radicchio with fontina . Ingredients :  ['thyme', 'radish', 'fontina', 'balsamic vinegar', 'olive oil']
#
# recommended recipe 1: Bresaola with rocket & artichokes . Ingredients :  ['parmesan', 'bresaola', 'balsamic vinegar', 'artichoke', 'olive oil']
#
# recommended recipe 2: Radish confetti with salsa verde . Ingredients :  ['anchovy', 'parsley', 'capers', 'mint', 'vinegar', 'radish', 'mustard', 'olive oil']
# =========================================
# current recipe :  Crisp prosciutto, pea & mozzarella salad with mint vinaigrette . Ingredients :  ['peas', 'orange', 'mint', 'cured ham', 'mozzarella', 'olive oil']
#
# recommended recipe 1: Radish confetti with salsa verde . Ingredients :  ['anchovy', 'parsley', 'capers', 'mint', 'vinegar', 'radish', 'mustard', 'olive oil']
#
# recommended recipe 2: Italian toasties . Ingredients :  ['ham', 'cheese', 'onion', 'mozzarella', 'oat bread', 'sundried tomato', 'olive', 'olive oil']
# ...
# =========================================
# current recipe :  Italian toasties . Ingredients :  ['ham', 'cheese', 'onion', 'mozzarella', 'oat bread', 'sundried tomato', 'olive', 'olive oil']
#
# recommended recipe 1: Italian stuffed chicken . Ingredients :  ['garlic', 'allherb and spice', 'cheese', 'tomato', 'olive', 'olive oil']
#
# recommended recipe 2: Italian-style stuffed aubergines . Ingredients :  ['garlic', 'cherry tomatoes', 'breadcrumb', 'eggplant', 'onion', 'mozzarella', 'basil', 'olive', 'olive oil']
# =========================================
# current recipe :  Italian broccoli & salmon bake . Ingredients :  ['anchovy', 'flour', 'mascarpone', 'cheddar', 'broccoli', 'salmon', 'capers', 'milk', 'basil', 'sundried tomato', 'butter', 'penne']
#
# recommended recipe 1: Italian veggie cottage pie . Ingredients :  ['garlic', 'oregano', 'flour', 'cheddar', 'potatoes', 'eggplant', 'olive oil', 'spinach', 'sundried tomato', 'milk']
#
# recommended recipe 2: Crusty cheddar pies . Ingredients :  ['flour', 'cheddar', 'peas', 'broccoli', 'potatoes', 'mustard', 'leek', 'yogurt', 'butter', 'celeriac', 'milk']
# =========================================
# current recipe :  Italian-style beef stew . Ingredients :  ['garlic', 'onion', 'pepper', 'beef', 'rosemary', 'tomato', 'olive', 'olive oil']
#
# recommended recipe 1: Italian stuffed chicken . Ingredients :  ['garlic', 'allherb and spice', 'cheese', 'tomato', 'olive', 'olive oil']
#
# recommended recipe 2: The best spaghetti bolognese recipe . Ingredients :  ['red wine', 'chili', 'parmesan', 'spaghetti', 'bay leaf', 'bacon', 'beef stock', 'garlic', 'oregano', 'rosemary', 'tomato', 'carrots', 'olive oil', 'beef mince', 'celery', 'cherry tomatoes', 'onion', 'basil', 'tomato sauce']
# =========================================
# current recipe :  Italian rice with chicken . Ingredients :  ['garlic', 'chicken stock', 'chicken breasts', 'rice', 'redskin onion', 'pepper', 'tomato', 'pesto', 'olive oil']
#
# recommended recipe 1: Chicken & chorizo jambalaya . Ingredients :  ['garlic', 'chicken stock', 'chicken breasts', 'chorizo', 'rice', 'onion', 'pepper', 'tomato', 'cajun spices', 'olive oil']
#
# recommended recipe 2: Mexican soup with chicken . Ingredients :  ['garlic', 'chicken stock', 'chili', 'chicken breasts', 'onion', 'lemon', 'tomato', 'cumin', 'olive oil']
# =========================================
# current recipe :  Italian stuffed chicken . Ingredients :  ['garlic', 'allherb and spice', 'cheese', 'tomato', 'olive', 'olive oil']
#
# recommended recipe 1: Italian-style beef stew . Ingredients :  ['garlic', 'onion', 'pepper', 'beef', 'rosemary', 'tomato', 'olive', 'olive oil']
#
# recommended recipe 2: Italian toasties . Ingredients :  ['ham', 'cheese', 'onion', 'mozzarella', 'oat bread', 'sundried tomato', 'olive', 'olive oil']
# =========================================
# current recipe :  Italian tuna balls . Ingredients :  ['parsley', 'spaghetti', 'breadcrumb', 'eggs', 'peanuts', 'common tuna', 'lemon', 'tomato paste']
#
# recommended recipe 1: Linguine with watercress & almond pesto . Ingredients :  ['garlic', 'parmesan', 'almond', 'spaghetti', 'sugar', 'lemon juice', 'olive oil']
#
# recommended recipe 2: Ricotta gnudi with sage butter . Ingredients :  ['parmesan', 'sage', 'ricotta', 'nutmeg', 'eggs', 'peanuts', 'redskin onion', 'butter', 'semolina']
# =========================================
# current recipe :  Italian stuffed courgettes . Ingredients :  ['garlic', 'parmesan', 'thyme', 'breadcrumb', 'sundried tomato', 'pine nuts', 'spring onion', 'salad', 'courgette', 'olive oil']
#
# recommended recipe 1: Italian-style stuffed aubergines . Ingredients :  ['garlic', 'cherry tomatoes', 'breadcrumb', 'eggplant', 'onion', 'mozzarella', 'basil', 'olive', 'olive oil']
#
# recommended recipe 2: Bresaola with rocket & artichokes . Ingredients :  ['parmesan', 'bresaola', 'balsamic vinegar', 'artichoke', 'olive oil']
# =========================================
# current recipe :  Italian sausage & chestnut pasta . Ingredients :  ['garlic', 'sausage', 'parmesan', 'parsley', 'fennel', 'red wine', 'tomato puree', 'pasta', 'onion', 'chestnut', 'rosemary', 'olive oil']
#
# recommended recipe 1: Mushroom risotto . Ingredients :  ['garlic', 'butter', 'parmesan', 'parsley', 'vegetable stock', 'onion', 'white wine', 'risotto rice', 'mushroom', 'olive oil']
#
# recommended recipe 2: Italian meatloaf . Ingredients :  ['garlic', 'beef mince', 'parmesan', 'tomato puree', 'breadcrumb', 'eggs', 'pancetta', 'onion']
# =========================================
# current recipe :  Italian cottage pie . Ingredients :  ['oregano', 'parmesan', 'potatoes', 'pancetta', 'beef', 'butter']
#
# recommended recipe 1: Italian meatloaf . Ingredients :  ['garlic', 'beef mince', 'parmesan', 'tomato puree', 'breadcrumb', 'eggs', 'pancetta', 'onion']
#
# recommended recipe 2: Cottage pie . Ingredients :  ['garlic', 'beef mince', 'flour', 'celery', 'thyme', 'cheddar', 'potatoes', 'tomato sauce', 'nutmeg', 'bay leaf', 'onion', 'milk', 'carrots', 'beef stock', 'butter', 'olive oil']
# =========================================
# current recipe :  Crisp Italian chicken & polenta . Ingredients :  ['garlic', 'parmesan', 'cherry tomatoes', 'chicken breasts', 'polenta', 'rosemary', 'olive oil']
#
# recommended recipe 1: Italian-style beef stew . Ingredients :  ['garlic', 'onion', 'pepper', 'beef', 'rosemary', 'tomato', 'olive', 'olive oil']
#
# recommended recipe 2: Summer-in-winter chicken . Ingredients :  ['cherry tomatoes', 'chicken breasts', 'creme fraiche', 'basil', 'pesto', 'olive oil']
# =========================================
# current recipe :  Italian chicken & butternut pie . Ingredients :  ['garlic', 'parmesan', 'flour', 'marjoram', 'chicken breasts', 'red wine', 'rowanberry', 'tomato sauce', 'pancetta', 'onion', 'butternut squash', 'olive oil']
#
# recommended recipe 1: Red wine risotto . Ingredients :  ['risotto rice', 'parmesan', 'red wine', 'onion', 'butter']
#
# recommended recipe 2: Italian meatloaf . Ingredients :  ['garlic', 'beef mince', 'parmesan', 'tomato puree', 'breadcrumb', 'eggs', 'pancetta', 'onion']
# =========================================
# current recipe :  Italian veggie cottage pie . Ingredients :  ['garlic', 'oregano', 'flour', 'cheddar', 'potatoes', 'eggplant', 'olive oil', 'spinach', 'sundried tomato', 'milk']
#
# recommended recipe 1: Courgette, potato & cheddar bread . Ingredients :  ['yeast', 'thyme', 'flour', 'cheddar', 'potatoes', 'courgette', 'olive oil']
#
# recommended recipe 2: Italian cottage pie . Ingredients :  ['oregano', 'parmesan', 'potatoes', 'pancetta', 'beef', 'butter']
# =========================================
# current recipe :  Roasted fish Italian style . Ingredients :  ['cherry tomatoes', 'pine nuts', 'basil', 'olive', 'fish', 'olive oil']
#
# recommended recipe 1: Italian-style stuffed aubergines . Ingredients :  ['garlic', 'cherry tomatoes', 'breadcrumb', 'eggplant', 'onion', 'mozzarella', 'basil', 'olive', 'olive oil']
#
# recommended recipe 2: Italian toasties . Ingredients :  ['ham', 'cheese', 'onion', 'mozzarella', 'oat bread', 'sundried tomato', 'olive', 'olive oil']
# =========================================
# current recipe :  Italian-style stuffed aubergines . Ingredients :  ['garlic', 'cherry tomatoes', 'breadcrumb', 'eggplant', 'onion', 'mozzarella', 'basil', 'olive', 'olive oil']
#
# recommended recipe 1: Roasted fish Italian style . Ingredients :  ['cherry tomatoes', 'pine nuts', 'basil', 'olive', 'fish', 'olive oil']
#
# recommended recipe 2: Italian toasties . Ingredients :  ['ham', 'cheese', 'onion', 'mozzarella', 'oat bread', 'sundried tomato', 'olive', 'olive oil']
# =========================================
# current recipe :  Italian apricot fool . Ingredients :  ['mascarpone', 'caster sugar', 'cream', 'apricot', 'biscuits', 'lemon', 'orange oil']
#
# recommended recipe 1: Next level tiramisu . Ingredients :  ['cocoa', 'vanilla', 'mascarpone', 'caster sugar', 'cream', 'biscuits', 'nutmeg', 'eggs', 'coffee', 'marsala wine', 'cocoa powder']
#
# recommended recipe 2: Strawberry parfait with Vin Santo, mascarpone & biscotti . Ingredients :  ['mascarpone', 'caster sugar', 'biscuits', 'strawberry', 'soured cream', 'white wine']
# =========================================
# current recipe :  Tiramisu ice-cream cake . Ingredients :  ['cocoa', 'chocolate', 'mascarpone', 'caster sugar', 'cream', 'biscuits', 'coffee', 'dark chocolate', 'marsala wine', 'brandy']
#
# recommended recipe 1: Best ever tiramisu . Ingredients :  ['cocoa', 'mascarpone', 'caster sugar', 'cream', 'sponge finger', 'coffee', 'dark chocolate', 'marsala wine']
#
# recommended recipe 2: Next level tiramisu . Ingredients :  ['cocoa', 'vanilla', 'mascarpone', 'caster sugar', 'cream', 'biscuits', 'nutmeg', 'eggs', 'coffee', 'marsala wine', 'cocoa powder']
# =========================================
# current recipe :  Best ever tiramisu . Ingredients :  ['cocoa', 'mascarpone', 'caster sugar', 'cream', 'sponge finger', 'coffee', 'dark chocolate', 'marsala wine']
#
# recommended recipe 1: Tiramisu ice-cream cake . Ingredients :  ['cocoa', 'chocolate', 'mascarpone', 'caster sugar', 'cream', 'biscuits', 'coffee', 'dark chocolate', 'marsala wine', 'brandy']
#
# recommended recipe 2: Next level tiramisu . Ingredients :  ['cocoa', 'vanilla', 'mascarpone', 'caster sugar', 'cream', 'biscuits', 'nutmeg', 'eggs', 'coffee', 'marsala wine', 'cocoa powder']
# =========================================
# current recipe :  Sherry, almond & orange pandoro . Ingredients :  ['almond', 'mascarpone', 'cream', 'icing sugar', 'orange', 'sherry']
#
# recommended recipe 1: Panettone . Ingredients :  ['raisins', 'yeast', 'vanilla', 'almond', 'caster sugar', 'icing sugar', 'bread', 'orange', 'eggs', 'lemon', 'raisin', 'rum', 'butter', 'milk']
#
# recommended recipe 2: Torta del Nonna . Ingredients :  ['flour', 'vanilla', 'caster sugar', 'ricotta', 'icing sugar', 'orange', 'eggs', 'pine nuts', 'dark chocolate', 'butter', 'milk']
# =========================================
# current recipe :  Torta del Nonna . Ingredients :  ['flour', 'vanilla', 'caster sugar', 'ricotta', 'icing sugar', 'orange', 'eggs', 'pine nuts', 'dark chocolate', 'butter', 'milk']
#
# recommended recipe 1: Orange polenta cake . Ingredients :  ['flour', 'caster sugar', 'baking powder', 'orange', 'eggs', 'polenta', 'butter']
#
# recommended recipe 2: Best ever chocolate brownies recipe . Ingredients :  ['flour', 'chocolate', 'caster sugar', 'eggs', 'dark chocolate', 'cocoa powder', 'butter']
# =========================================
# current recipe :  Orange polenta cake . Ingredients :  ['flour', 'caster sugar', 'baking powder', 'orange', 'eggs', 'polenta', 'butter']
#
# recommended recipe 1: Torta del Nonna . Ingredients :  ['flour', 'vanilla', 'caster sugar', 'ricotta', 'icing sugar', 'orange', 'eggs', 'pine nuts', 'dark chocolate', 'butter', 'milk']
#
# recommended recipe 2: Caramelised apple cake with streusel topping . Ingredients :  ['flour', 'vanilla', 'baking powder', 'ground cinnamon', 'eggs', 'demerara sugar', 'light brown sugar', 'butter', 'apple', 'hazelnut', 'milk']
# =========================================
# current recipe :  Vanilla panna cotta . Ingredients :  ['gelatin', 'vanilla', 'caster sugar', 'cream', 'strawberry', 'milk']
#
# recommended recipe 1: Strawberry cheesecake in 4 easy steps . Ingredients :  ['vanilla', 'cream', 'biscuits', 'strawberry', 'sugar', 'cream cheese', 'butter']
#
# recommended recipe 2: Strawberry parfait with Vin Santo, mascarpone & biscotti . Ingredients :  ['mascarpone', 'caster sugar', 'biscuits', 'strawberry', 'soured cream', 'white wine']
# =========================================
# current recipe :  Next level tiramisu . Ingredients :  ['cocoa', 'vanilla', 'mascarpone', 'caster sugar', 'cream', 'biscuits', 'nutmeg', 'eggs', 'coffee', 'marsala wine', 'cocoa powder']
#
# recommended recipe 1: Iced hazelnut zabagliones . Ingredients :  ['chocolate', 'caster sugar', 'cream', 'eggs', 'coffee', 'marsala wine', 'hazelnut']
#
# recommended recipe 2: Tiramisu ice-cream cake . Ingredients :  ['cocoa', 'chocolate', 'mascarpone', 'caster sugar', 'cream', 'biscuits', 'coffee', 'dark chocolate', 'marsala wine', 'brandy']
# =========================================
# current recipe :  Strawberry & mint granita . Ingredients :  ['strawberry', 'mint', 'caster sugar']
#
# recommended recipe 1: Medley of summer fruits . Ingredients :  ['vanilla', 'caster sugar', 'red wine', 'strawberry', 'melon', 'mint', 'raspberry', 'basil', 'white wine']
#
# recommended recipe 2: Vanilla panna cotta . Ingredients :  ['gelatin', 'vanilla', 'caster sugar', 'cream', 'strawberry', 'milk']
# =========================================
# current recipe :  Panettone . Ingredients :  ['raisins', 'yeast', 'vanilla', 'almond', 'caster sugar', 'icing sugar', 'bread', 'orange', 'eggs', 'lemon', 'raisin', 'rum', 'butter', 'milk']
#
# recommended recipe 1: Torta del Nonna . Ingredients :  ['flour', 'vanilla', 'caster sugar', 'ricotta', 'icing sugar', 'orange', 'eggs', 'pine nuts', 'dark chocolate', 'butter', 'milk']
#
# recommended recipe 2: Sherry, almond & orange pandoro . Ingredients :  ['almond', 'mascarpone', 'cream', 'icing sugar', 'orange', 'sherry']
# =========================================
# current recipe :  Zabaglione trifle slice . Ingredients :  ['cocoa', 'cherry tomatoes', 'cream', 'caster sugar', 'eggs', 'marsala wine', 'white wine']
#
# recommended recipe 1: Iced hazelnut zabagliones . Ingredients :  ['chocolate', 'caster sugar', 'cream', 'eggs', 'coffee', 'marsala wine', 'hazelnut']
#
# recommended recipe 2: Best ever tiramisu . Ingredients :  ['cocoa', 'mascarpone', 'caster sugar', 'cream', 'sponge finger', 'coffee', 'dark chocolate', 'marsala wine']
# =========================================
# current recipe :  Toasted marshmallow & ginger cake . Ingredients :  ['flour', 'caster sugar', 'bicarbonate of soda', 'cinnamon', 'icing sugar', 'golden syrup sugar', 'eggs', 'black treacle', 'light brown sugar', 'ginger', 'butter', 'milk']
#
# recommended recipe 1: Chocolate brownie cake . Ingredients :  ['butter', 'flour', 'chocolate', 'vanilla', 'caster sugar', 'golden syrup sugar', 'eggs', 'light brown sugar', 'cocoa powder', 'baking powder']
#
# recommended recipe 2: Easy chocolate fudge cake . Ingredients :  ['butter', 'self-raising flour', 'caster sugar', 'golden syrup sugar', 'eggs', 'sunflower oil', 'sugar', 'cocoa powder', 'baking powder', 'milk']
# =========================================
# current recipe :  Iced hazelnut zabagliones . Ingredients :  ['chocolate', 'caster sugar', 'cream', 'eggs', 'coffee', 'marsala wine', 'hazelnut']
#
# recommended recipe 1: Next level tiramisu . Ingredients :  ['cocoa', 'vanilla', 'mascarpone', 'caster sugar', 'cream', 'biscuits', 'nutmeg', 'eggs', 'coffee', 'marsala wine', 'cocoa powder']
#
# recommended recipe 2: Tiramisu ice-cream cake . Ingredients :  ['cocoa', 'chocolate', 'mascarpone', 'caster sugar', 'cream', 'biscuits', 'coffee', 'dark chocolate', 'marsala wine', 'brandy']
# =========================================

# %%
len(recipes_name)
# Out:
# 115
